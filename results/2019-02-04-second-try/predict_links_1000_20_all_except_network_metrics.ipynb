# %% [markdown]
# # Amazon Copurchased

# %% [markdown]
# This is a Python notebook created using "jupyter".
#
# Author: Rafael J. P. dos Santos

# %% [markdown]
# ## Condições do experimento

# %% [markdown]
# * Todos os dados
# * Todas as features exceto métricas de rede

# %% [markdown]
# ## Parameters

# %% [markdown]
# We use the parameter below to set the maximum number of edges to be read from the CSV containing edges (links).

# %%
max_edges = 0 # Set quantity to read from file
edges_csv_file = "data/20180812_links"
nodes_csv_file = "data/20180812_nodes"
features = 'all'
n_estimators = 20

# %%
# Parameters
n_estimators = 20
max_edges = 1000
features = "all_except_network_metrics"

# %% [markdown]
# ## Load the libraries

# %% [markdown]
# Let's load the Python libraries that we will need throughout the script

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport shared_functions
import pandas as pd
from __future__ import division
import shared_functions

# %% [markdown]
# ## Read graph

# %% [markdown]
# ### Read only first lines of datafile

# %% [markdown]
# Due to slowness in calculating centrality measures, we use the parameter provided in the beggining of the script to limit the number of edges we will read.

# %%
G = shared_functions.read_G(edges_csv_file, max_edges)
# Out:
# Using 1000 edges out of 229338 available (0.44% of data)

# %% [markdown]
# ### Calculate nodes centrality measures

# %% [markdown]
# Now that we have our NetworkX graph, let's calculate some centrality measures for every node.

# %%
centrality_measures = shared_functions.centrality_measures(G)
print centrality_measures.keys()
# Out:
# ['eigenvector_centrality', 'degree', 'betweenness_centrality']

# %% [markdown]
# #### Has link with node 1?

# %%
centrality_measures['has_link_to_node_1'] = shared_functions.has_link_to_node(G, 1)

# %% [markdown]
# ### Load node properties

# %% [markdown]
# Let's load the CSV containing the nodes data (title, price) into a Pandas dataframe, and append the centrality measures calculated above.

# %%
df = pd.read_csv(nodes_csv_file)

# %%
df = shared_functions.add_sha256_column_from_id(df)
df = shared_functions.merge_columns(df, centrality_measures)

# %% [markdown]
# ### Let's convert some fields to numeric

# %%
categorical_features = [
    'category1',
    'category2',
    'category3',
    'category4',
    'category5',
    'category6',
    'category7',
    'category8',
    'category9',
    'category10',
    'language',
    'coverType',
    'publisher',
    'rankingCategory'
]

numeric_features = [
    'ranking',
    'reviewCount',
    'pages',
    'weight',
    'height',
    'width',
    'depth',
    'rating'
]

if features == 'all':
    numeric_features.extend([
        'degree',
        'eigenvector_centrality',
        'betweenness_centrality', 
    ])

if features == 'none':
    categorical_features = []
    numeric_features = []

df = shared_functions.prepare_data(df, numeric_features)

# %% [markdown]
# ### Remove nodes without price and outliers

# %%
df = df.drop(df[df["price"].isnull()].index)
#df = df.drop(df[df["price"] > 500].index)

# %% [markdown]
# ### Inspect columns

# %%
df.columns
# Out:
# Index([u'id', u'title', u'url', u'authors', u'coverType', u'publisher',
#        u'edition', u'publicationDate', u'rankingCategory', u'category1',
#        u'category2', u'category3', u'category4', u'category5', u'category6',
#        u'category7', u'category8', u'category9', u'category10', u'isbn10',
#        u'isbn13', u'language', u'postProcessed', u'price', u'ranking',
#        u'pages', u'reviewCount', u'rating', u'width', u'height', u'depth',
#        u'weight', u'sha256_id', u'has_link_to_node_1',
#        u'eigenvector_centrality', u'degree', u'betweenness_centrality'],
#       dtype='object')

# %% [markdown]
# ### Features summary

# %% [markdown]
# Below we have a summary of the Pandas dataframe. We can see the number of nodes that we are actually analyzing, which depends on the max_edges parameter defined before.

# %%
df.describe(include='all')
# Out:
#                  id                                              title  \
# count    323.000000                                                323
# unique          NaN                                                323
# top             NaN  Introduction to Differential Geometry of Space...
# freq            NaN                                                  1
# mean    1223.699690                                                NaN
# std      983.671554                                                NaN
# min        1.000000                                                NaN
# 25%       94.500000                                                NaN
# 50%     1713.000000                                                NaN
# 75%     1989.000000                                                NaN
# max     6474.000000                                                NaN
#
#                                              url                  authors  \
# count                                        323                      323
# unique                                       323                      281
# top     https://www.amazon.com.br/dp/0521864496/  Wolfgang Pauli (Autor),
# freq                                           1                        5
# mean                                         NaN                      NaN
# std                                          NaN                      NaN
# min                                          NaN                      NaN
# 25%                                          NaN                      NaN
# 50%                                          NaN                      NaN
# 75%                                          NaN                      NaN
# max                                          NaN                      NaN
#
#          coverType           publisher  edition       publicationDate  \
# count          318                 319      0.0                   100
# unique           2                  80      NaN                    98
# top     Capa comum  Dover Publications      NaN  25 de agosto de 2017
# freq           205                  60      NaN                     2
# mean           NaN                 NaN      NaN                   NaN
# std            NaN                 NaN      NaN                   NaN
# min            NaN                 NaN      NaN                   NaN
# 25%            NaN                 NaN      NaN                   NaN
# 50%            NaN                 NaN      NaN                   NaN
# 75%            NaN                 NaN      NaN                   NaN
# max            NaN                 NaN      NaN                   NaN
#
#        rankingCategory category1          ...                rating  \
# count              222       222          ...            323.000000
# unique               1         1          ...                   NaN
# top             Livros    Livros          ...                   NaN
# freq               222       222          ...                   NaN
# mean               NaN       NaN          ...              4.618436
# std                NaN       NaN          ...              0.299609
# min                NaN       NaN          ...              1.000000
# 25%                NaN       NaN          ...              4.621333
# 50%                NaN       NaN          ...              4.621333
# 75%                NaN       NaN          ...              4.621333
# max                NaN       NaN          ...              5.000000
#
#              width      height       depth      weight     sha256_id  \
# count   323.000000  323.000000  323.000000  323.000000  3.230000e+02
# unique         NaN         NaN         NaN         NaN           NaN
# top            NaN         NaN         NaN         NaN           NaN
# freq           NaN         NaN         NaN         NaN           NaN
# mean     16.569220   23.543504    2.465214  518.774013  2.021522e+09
# std       2.560235    2.103398    1.150573  212.103858  1.181879e+09
# min      10.000000   17.000000    0.500000   40.800000  1.612626e+07
# 25%      14.600000   22.200000    1.600000  381.000000  1.053793e+09
# 50%      16.000000   23.400000    2.300000  523.418147  1.958414e+09
# 75%      18.400000   24.700000    3.200000  649.000000  2.932558e+09
# max      25.400000   29.000000    6.400000  998.000000  4.245651e+09
#
#         has_link_to_node_1  eigenvector_centrality      degree  \
# count           323.000000              323.000000  323.000000
# unique                 NaN                     NaN         NaN
# top                    NaN                     NaN         NaN
# freq                   NaN                     NaN         NaN
# mean              0.058824                0.031843    5.702786
# std               0.235659                0.044428   12.686554
# min               0.000000                0.000665    1.000000
# 25%               0.000000                0.005899    1.000000
# 50%               0.000000                0.015397    2.000000
# 75%               0.000000                0.041038    5.000000
# max               1.000000                0.332948   97.000000
#
#        betweenness_centrality
# count              323.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                 0.012488
# std                  0.033616
# min                  0.000000
# 25%                  0.000000
# 50%                  0.002588
# 75%                  0.007882
# max                  0.255724
#
# [11 rows x 37 columns]

# %% [markdown]
# Below we can inspect the first rows of data, containing title, price, degree and other centrality measures.

# %%
df.head(10)
# Out:
#    id                                              title  \
# 0   1  The Stanford Mathematics Problem Book: With Hi...
# 1   2                                     Fourier Series
# 2   3               Probability Theory: A Concise Course
# 3   4  Vectors, Tensors and the Basic Equations of Fl...
# 4   5                    Ordinary Differential Equations
# 5   6            The Variational Principles of Mechanics
# 6   7                A First Look at Perturbation Theory
# 7   8  Thermodynamics and the Kinetic Theory of Gases...
# 8   9                                          Mechanics
# 9  10                         Statistical Thermodynamics
#
#                                         url                       authors  \
# 0  https://www.amazon.com.br/dp/0486469247/         George Polya (Autor),
# 1  https://www.amazon.com.br/dp/0486633179/    Georgi P. Tolstov (Autor),
# 2  https://www.amazon.com.br/dp/0486635449/        Y. A. Rozanov (Autor),
# 3  https://www.amazon.com.br/dp/0486661105/      Rutherford Aris (Autor),
# 4  https://www.amazon.com.br/dp/0486649407/     Morris Tenenbaum (Autor),
# 5  https://www.amazon.com.br/dp/0486650677/    Cornelius Lanczos (Autor),
# 6  https://www.amazon.com.br/dp/0486675513/     James G. Simmonds (Autor)
# 7  https://www.amazon.com.br/dp/0486414612/       Wolfgang Pauli (Autor),
# 8  https://www.amazon.com.br/dp/0486607542/  Jacob P. Den Hartog (Autor),
# 9  https://www.amazon.com.br/dp/0486661016/    Erwin Schrodinger (Autor),
#
#     coverType                publisher  edition          publicationDate  \
# 0  Capa comum       Dover Publications      NaN  19 de fevereiro de 2009
# 1  Capa comum       Dover Publications      NaN       1 de junho de 1976
# 2  Capa comum       Dover Publications      NaN                      NaN
# 3  Capa comum       Dover Publications      NaN                      NaN
# 4  Capa comum       Dover Publications      NaN                      NaN
# 5  Capa comum       Dover Publications      NaN                      NaN
# 6  Capa comum  Dover Publications Inc.      NaN                      NaN
# 7  Capa comum       Dover Publications      NaN    18 de outubro de 2010
# 8  Capa comum       Dover Publications      NaN       1 de junho de 1961
# 9  Capa comum       Dover Publications      NaN                      NaN
#
#   rankingCategory category1          ...              rating width height  \
# 0          Livros    Livros          ...            4.000000  14.0   21.0
# 1          Livros    Livros          ...            4.600000  14.6   21.0
# 2          Livros    Livros          ...            4.621333  14.4   20.8
# 3          Livros    Livros          ...            4.500000  13.7   21.5
# 4          Livros    Livros          ...            4.500000  13.8   21.8
# 5          Livros    Livros          ...            5.000000  13.8   21.5
# 6          Livros    Livros          ...            4.621333  13.7   21.5
# 7          Livros    Livros          ...            5.000000  13.8   21.6
# 8          Livros    Livros          ...            4.621333  13.6   20.3
# 9          Livros    Livros          ...            4.621333  14.0   20.3
#
#   depth weight   sha256_id  has_link_to_node_1  eigenvector_centrality  \
# 0   0.6  181.0  3564330554                   0                0.060815
# 1   1.9  363.0  1309098117                   1                0.222710
# 2   0.8  200.0  1260550007                   1                0.228632
# 3   1.6  381.0  4012708477                   1                0.074234
# 4   4.0  939.0  3891707921                   0                0.302139
# 5   2.2  581.0  2030201243                   0                0.147241
# 6   0.8  159.0   744636978                   0                0.032750
# 7   1.0  159.0   425205287                   0                0.013043
# 8   2.3  522.0  1246026773                   0                0.089906
# 9   1.3  159.0  1338518310                   0                0.030397
#
#    degree betweenness_centrality
# 0      19               0.019856
# 1      62               0.150406
# 2      59               0.145841
# 3      18               0.061018
# 4      88               0.184908
# 5      43               0.096699
# 6       9               0.012768
# 7      10               0.075108
# 8      23               0.084144
# 9      15               0.053560
#
# [10 rows x 37 columns]

# %% [markdown]
# ## Random forest using multiple features, has_link_to_node_1 as target

# %% [markdown]
# ### Preparing data

# %%
target, features, feature_list, validation_features, validation_target = shared_functions.prepare_datasets(df, numeric_features, categorical_features, 'has_link_to_node_1')
# Out:
# Numeric features:  ['ranking', 'reviewCount', 'pages', 'weight', 'height', 'width', 'depth', 'rating']
# Categorical features:  ['category1', 'category2', 'category3', 'category4', 'category5', 'category6', 'category7', 'category8', 'category9', 'category10', 'language', 'coverType', 'publisher', 'rankingCategory']
# Target column:  has_link_to_node_1
# Test percentage:  0.201238390093
# Train features shape:  (258, 195)
# Train target shape:  (258,)
# Test features shape:  (65, 195)
# Test target shape:  (65,)

# %% [markdown]
# ### Cross validation

# %% [markdown]
# #### Run cross val

# %%
estimators, splits, scores = shared_functions.run_cross_validation_classification(features, target, n_estimators = n_estimators)

# %% [markdown]
# #### Cross val confusion matrices

# %%
shared_functions.plot_splits_confusion_matrices(features, target, splits, estimators, threshold = 0.5)
# Out:
# Splits quantity:  10
# Splits lenghts:  [27, 27, 26, 26, 26, 26, 25, 25, 25, 25]
# X shape:  (258, 195)
# y shape:  (258,)
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# #### List of most important features

# %%
shared_functions.get_most_important_features(estimators, feature_list)
# Out:
#                                  feature  mean importance       std  std/mean
# 0                              sha256_id        12.287518  7.038219  0.572794
# 1                                ranking        10.669835  5.652156  0.529732
# 2                                  width         9.509652  6.702390  0.704799
# 3                                 height         8.560462  3.706413  0.432969
# 4                                  pages         8.095701  4.889254  0.603932
# 5                                 weight         7.784727  3.467265  0.445393
# 6                                  depth         6.386217  5.003498  0.783484
# 7                       category4_Física         5.199966  1.837289  0.353327
# 8                                 rating         4.821590  2.317995  0.480753
# 9                            reviewCount         4.236856  2.949904  0.696248
# 10  publisher_Cambridge University Press         3.566248  1.739927  0.487887
# 11                    language_Português         2.648985  1.743824  0.658299
# 12             category5_Matemática Pura         2.283951  0.718365  0.314527
# 13                   coverType_Capa dura         1.862805  2.366673  1.270489
# 14     publisher_Dover Publications Inc.         1.816892  0.791737  0.435765
# 15                      category3_Física         0.748488  0.509555  0.680779
# 16                  publisher_OUP Oxford         0.719656  0.717862  0.997508
# 17          publisher_Dover Publications         0.548079  0.722780  1.318753
# 18             category5_Teoria Quântica         0.536680  0.540309  1.006762
# 19       category3_Ciências Tecnológicas         0.380137  1.202099  3.162278

# %% [markdown]
# #### Predicted vs real

# %%
y_pred = shared_functions.get_all_predictions_from_splits(features, target, splits, estimators)
labels = {0: u'Sem ligação', 1: u'Com ligação'}
shared_functions.plot_splits_predicted_vs_real(target, y_pred, title=u'Probabilidade de ligação estimada pelo modelo vs. Ligação real', ylabel=u'Probabilidade de ligação estimada pelo modelo', xlabel=u'Ligação real (0 = Ausência, 1 = Presença)', legend = False, labels = labels)
# Out:
# Splits quantity:  10
# Splits lenghts:  [27, 27, 26, 26, 26, 26, 25, 25, 25, 25]
# X shape:  (258, 195)
# y shape:  (258,)

# %% [markdown]
# #### Probability density

# %%
shared_functions.print_classification_probability_distribution(target, y_pred)
# Out:
# (258,)

# %% [markdown]
# #### ROC Curve

# %%
closest_to_optimal_probability = shared_functions.plot_roc_curve(target, y_pred)

# %%
shared_functions.plot_splits_confusion_matrices(features, target, splits, estimators, threshold = closest_to_optimal_probability)
# Out:
# Splits quantity:  10
# Splits lenghts:  [27, 27, 26, 26, 26, 26, 25, 25, 25, 25]
# X shape:  (258, 195)
# y shape:  (258,)
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Normalized confusion matrix
