# %% [markdown]
# # Amazon Copurchased

# %% [markdown]
# This is a Python notebook created using "jupyter".
#
# Author: Rafael J. P. dos Santos

# %% [markdown]
# ## Parameters

# %% [markdown]
# We use the parameter below to set the maximum number of edges to be read from the CSV containing edges (links).

# %%
max_edges = 200000 # Set quantity to read from file
edges_csv_file = "data/20180812_links"
nodes_csv_file = "data/20180812_nodes"

# %% [markdown]
# ## Load the libraries

# %% [markdown]
# Let's load the Python libraries that we will need throughout the script

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import export_graphviz
import pydot
from sklearn.ensemble import RandomForestRegressor
from __future__ import division
import sklearn
#from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
import hashlib
import sys
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.20.2.

# %% [markdown]
# ## Read graph

# %% [markdown]
# ### Read only first lines of datafile

# %% [markdown]
# Due to slowness in calculating centrality measures, we use the parameter provided in the beggining of the script to limit the number of edges we will read.

# %%
lines = []
total_line_count = 0
with open(edges_csv_file, 'rb') as f:
    f.readline()   # skip first line / header
    while True:
        line = f.readline()
        if not line:
            break
        if not (max_edges > 0 and len(lines) >= max_edges):
            lines.append(line)
        total_line_count += 1
G = nx.parse_edgelist(lines, delimiter=',', nodetype=int)

# %%
print "Using %d edges out of %d available (%.2f%% of data)" % (len(lines), total_line_count, len(lines)/total_line_count * 100)
# Out:
# Using 200000 edges out of 229338 available (87.21% of data)

# %% [markdown]
# ### Calculate nodes centrality measures

# %% [markdown]
# Now that we have our NetworkX graph, let's calculate some centrality measures for every node.

# %%
centrality_measures = {}

# %% [markdown]
# #### Degree

# %%
centrality_measures["degree"] = nx.degree(G)

# %% [markdown]
# #### Eigenvector centrality

# %%
centrality_measures["eigenvector_centrality"] = nx.eigenvector_centrality_numpy(G)

# %% [markdown]
# ####  Approximate betweenness centrality (current flow)

# %%
centrality_measures["betweenness_centrality"] = nx.approximate_current_flow_betweenness_centrality(G)

# %% [markdown]
# #### Closeness centrality

# %%
# Very slow!
centrality_measures["closeness_centrality"] = nx.closeness_centrality(G)

# %% [markdown]
# #### Betweenness centrality

# %%
# Very slow!
centrality_measures["betweenness_centrality"] = nx.betweenness_centrality(G)

# %% [markdown]
# ### Load node properties

# %% [markdown]
# Let's load the CSV containing the nodes data (title, price) into a Pandas dataframe, and append the centrality measures calculated above.

# %%
df = pd.read_csv(nodes_csv_file)

# %% [markdown]
# ####  Convert ID to random int to avoid leaking knowledge

# %%
sha256_ids = df['id'].map(lambda x: int(hashlib.sha256(str(x)).hexdigest()[0:8], 16))

# %%
# Add columns to dataframe
def merge_columns(dataframe, data):
    df = dataframe.copy()
    for col in data:
        rows = []
        for item in data[col].items():
            rows.append({"id": item[0], col: item[1]})
        df = df.merge(pd.DataFrame(rows))
    return df

df = merge_columns(df, centrality_measures)
df = merge_columns(df, {'sha256_id': sha256_ids})

# %% [markdown]
# ### Let's convert some fields to numeric

# %%
categorical_features = [
    'category1',
    'category2',
    'category3',
    'category4',
    'category5',
    'category6',
    'category7',
    'category8',
    'category9',
    'category10',
    'language',
    'coverType',
    'publisher',
    'rankingCategory',
    'authors'
]

numeric_features = [
    'degree',
    'eigenvector_centrality',
    'betweenness_centrality',
    'ranking',
    'reviewCount',
    'pages',
    'weight',
    'height',
    'width',
    'depth',
    'rating'
]

df = df.replace("<<MISSING_DATA>>", np.NaN)
df[numeric_features] = df[numeric_features].apply(pd.to_numeric)
df[['price']] = df[['price']].apply(pd.to_numeric)

for feature in numeric_features:
    df[feature].fillna(df[feature].mean(), inplace = True)

# %% [markdown]
# ### Remove nodes without price

# %%
df = df.drop(df[df["price"].isnull()].index)
#df = df.drop(df[df["price"] > 500].index)

# %% [markdown]
# ### Inspect columns

# %%
df.columns
# Out:
# Index([u'id', u'title', u'url', u'authors', u'coverType', u'publisher',
#        u'edition', u'publicationDate', u'rankingCategory', u'category1',
#        u'category2', u'category3', u'category4', u'category5', u'category6',
#        u'category7', u'category8', u'category9', u'category10', u'isbn10',
#        u'isbn13', u'language', u'postProcessed', u'price', u'ranking',
#        u'pages', u'reviewCount', u'rating', u'width', u'height', u'depth',
#        u'weight', u'eigenvector_centrality', u'degree',
#        u'betweenness_centrality', u'sha256_id'],
#       dtype='object')

# %% [markdown]
# ### Features summary

# %% [markdown]
# Below we have a summary of the Pandas dataframe. We can see the number of nodes that we are actually analyzing, which depends on the max_edges parameter defined before.

# %%
df.describe(include='all')
# Out:
#                  id          title                                       url  \
# count   9035.000000           9035                                      9035
# unique          NaN           8836                                      9035
# top             NaN  Macroeconomia  https://www.amazon.com.br/dp/8580332990/
# freq            NaN              6                                         1
# mean    4842.756613            NaN                                       NaN
# std     2804.433223            NaN                                       NaN
# min        1.000000            NaN                                       NaN
# 25%     2449.500000            NaN                                       NaN
# 50%     4839.000000            NaN                                       NaN
# 75%     7256.500000            NaN                                       NaN
# max     9770.000000            NaN                                       NaN
#
#                        authors   coverType             publisher  edition  \
# count                     9034        8924                  8940      0.0
# unique                    6089          11                   718      NaN
# top     Vários Autores (Autor)  Capa comum  Companhia das Letras      NaN
# freq                       105        7634                   529      NaN
# mean                       NaN         NaN                   NaN      NaN
# std                        NaN         NaN                   NaN      NaN
# min                        NaN         NaN                   NaN      NaN
# 25%                        NaN         NaN                   NaN      NaN
# 50%                        NaN         NaN                   NaN      NaN
# 75%                        NaN         NaN                   NaN      NaN
# max                        NaN         NaN                   NaN      NaN
#
#              publicationDate rankingCategory category1      ...       \
# count                    766            8708      8596      ...
# unique                   563               1         1      ...
# top     1 de janeiro de 2014          Livros    Livros      ...
# freq                      13            8708      8596      ...
# mean                     NaN             NaN       NaN      ...
# std                      NaN             NaN       NaN      ...
# min                      NaN             NaN       NaN      ...
# 25%                      NaN             NaN       NaN      ...
# 50%                      NaN             NaN       NaN      ...
# 75%                      NaN             NaN       NaN      ...
# max                      NaN             NaN       NaN      ...
#
#         reviewCount       rating        width       height        depth  \
# count   9035.000000  9035.000000  9035.000000  9035.000000  9035.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      14.477309     4.443981    15.285344    22.273543     2.077967
# std       32.851683     0.552983     2.577994     2.592354     1.205328
# min        1.000000     1.000000     0.800000     8.600000     0.200000
# 25%        2.000000     4.400000    13.600000    20.800000     1.300000
# 50%       10.000000     4.445410    15.400000    22.600000     1.800000
# 75%       14.387655     4.800000    16.000000    23.200000     2.600000
# max      755.000000     5.000000    35.500000    53.200000    17.800000
#
#              weight  eigenvector_centrality       degree  \
# count   9035.000000            9.035000e+03  9035.000000
# unique          NaN                     NaN          NaN
# top             NaN                     NaN          NaN
# freq            NaN                     NaN          NaN
# mean     426.177007            3.672992e-03    29.429441
# std      201.984877            9.781720e-03    34.829986
# min        4.500000            7.044110e-11     1.000000
# 25%      281.000000            1.349866e-05     6.000000
# 50%      426.812584            1.988690e-04    17.000000
# 75%      540.000000            1.874969e-03    40.000000
# max      998.000000            1.455302e-01   474.000000
#
#         betweenness_centrality     sha256_id
# count              9035.000000  9.035000e+03
# unique                     NaN           NaN
# top                        NaN           NaN
# freq                       NaN           NaN
# mean                  0.001075  2.122120e+09
# std                   0.001748  1.241029e+09
# min                   0.000000  2.291770e+05
# 25%                   0.000170  1.026225e+09
# 50%                   0.000513  2.111599e+09
# 75%                   0.001336  3.184873e+09
# max                   0.031973  4.294447e+09
#
# [11 rows x 36 columns]

# %% [markdown]
# Below we can inspect the first rows of data, containing title, price, degree and other centrality measures.

# %%
df.head(10)
# Out:
#    id                                              title  \
# 0   1  The Stanford Mathematics Problem Book: With Hi...
# 1   2                                     Fourier Series
# 2   3               Probability Theory: A Concise Course
# 3   4  Vectors, Tensors and the Basic Equations of Fl...
# 4   5                    Ordinary Differential Equations
# 5   6            The Variational Principles of Mechanics
# 6   7                A First Look at Perturbation Theory
# 7   8  Thermodynamics and the Kinetic Theory of Gases...
# 8   9                                          Mechanics
# 9  10                         Statistical Thermodynamics
#
#                                         url                       authors  \
# 0  https://www.amazon.com.br/dp/0486469247/         George Polya (Autor),
# 1  https://www.amazon.com.br/dp/0486633179/    Georgi P. Tolstov (Autor),
# 2  https://www.amazon.com.br/dp/0486635449/        Y. A. Rozanov (Autor),
# 3  https://www.amazon.com.br/dp/0486661105/      Rutherford Aris (Autor),
# 4  https://www.amazon.com.br/dp/0486649407/     Morris Tenenbaum (Autor),
# 5  https://www.amazon.com.br/dp/0486650677/    Cornelius Lanczos (Autor),
# 6  https://www.amazon.com.br/dp/0486675513/     James G. Simmonds (Autor)
# 7  https://www.amazon.com.br/dp/0486414612/       Wolfgang Pauli (Autor),
# 8  https://www.amazon.com.br/dp/0486607542/  Jacob P. Den Hartog (Autor),
# 9  https://www.amazon.com.br/dp/0486661016/    Erwin Schrodinger (Autor),
#
#     coverType                publisher  edition          publicationDate  \
# 0  Capa comum       Dover Publications      NaN  19 de fevereiro de 2009
# 1  Capa comum       Dover Publications      NaN       1 de junho de 1976
# 2  Capa comum       Dover Publications      NaN                      NaN
# 3  Capa comum       Dover Publications      NaN                      NaN
# 4  Capa comum       Dover Publications      NaN                      NaN
# 5  Capa comum       Dover Publications      NaN                      NaN
# 6  Capa comum  Dover Publications Inc.      NaN                      NaN
# 7  Capa comum       Dover Publications      NaN    18 de outubro de 2010
# 8  Capa comum       Dover Publications      NaN       1 de junho de 1961
# 9  Capa comum       Dover Publications      NaN                      NaN
#
#   rankingCategory category1     ...     reviewCount   rating width height  \
# 0          Livros    Livros     ...        1.000000  4.00000  14.0   21.0
# 1          Livros    Livros     ...        3.000000  4.60000  14.6   21.0
# 2          Livros    Livros     ...       14.387655  4.44541  14.4   20.8
# 3          Livros    Livros     ...        2.000000  4.50000  13.7   21.5
# 4          Livros    Livros     ...        4.000000  4.50000  13.8   21.8
# 5          Livros    Livros     ...        1.000000  5.00000  13.8   21.5
# 6          Livros    Livros     ...       14.387655  4.44541  13.7   21.5
# 7          Livros    Livros     ...        2.000000  5.00000  13.8   21.6
# 8          Livros    Livros     ...       14.387655  4.44541  13.6   20.3
# 9          Livros    Livros     ...       14.387655  4.44541  14.0   20.3
#
#   depth weight  eigenvector_centrality  degree  betweenness_centrality  \
# 0   0.6  181.0            1.809167e-05      19                0.001231
# 1   1.9  363.0            4.384870e-06      62                0.002139
# 2   0.8  200.0            5.482230e-06      59                0.004549
# 3   1.6  381.0            1.124264e-06      18                0.001047
# 4   4.0  939.0            7.710523e-06      88                0.004518
# 5   2.2  581.0            9.659183e-06      43                0.001942
# 6   0.8  159.0            4.900114e-07       9                0.000162
# 7   1.0  159.0            1.910403e-05      10                0.001633
# 8   2.3  522.0            1.806360e-06      23                0.001177
# 9   1.3  159.0            1.395149e-06      15                0.000937
#
#     sha256_id
# 0  3564330554
# 1  1309098117
# 2  1260550007
# 3  4012708477
# 4  3891707921
# 5  2030201243
# 6   744636978
# 7   425205287
# 8  1246026773
# 9  1338518310
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Random forest using various features, price as target

# %% [markdown]
# ### Preparing data

# %%
df_with_dummies = pd.get_dummies(df[['sha256_id'] + numeric_features + categorical_features + ['price']],columns=categorical_features,drop_first=True)

# %%
feature_list = list(df_with_dummies.drop(columns = ['price']))

features_values = np.array(df_with_dummies.drop(columns = ['price']))
target_value = np.array(df_with_dummies['price'])

features_and_target = np.concatenate((features_values, target_value.reshape(len(target_value), 1)), axis = 1)

#print features_and_target.shape

# Shuffle features_and_target
np.random.shuffle(features_and_target)

limit = int(round(len(target_value) * 0.8))
print "Test percentage", (len(target_value)-limit)/len(target_value)

features = features_and_target[:limit, :-1]
target = features_and_target[:limit, -1]

test_features = features_and_target[limit:, :-1]
test_target = features_and_target[limit: , -1]

print "Train features shape", features.shape
print "Train target shape", target.shape
print "Test features shape", test_features.shape
print "Test target shape", test_target.shape
# Out:
# Test percentage 0.2
# Train features shape (7228, 7893)
# Train target shape (7228,)
# Test features shape (1807, 7893)
# Test target shape (1807,)

# %% [markdown]
# ### Average price as baseline

# %% [markdown]
# It's important to have a baseline, so we can validate our predictions after running our model. One easy choice for baseline is the average price of a book.
#
# We have an average price around R\$43, so this means that a very easy prediction would be to always guess R$43 for the price of any book.

# %%
average_target = np.average(target)
print "Average price: R$", average_target
# Out:
# Average price: R$ 72.7154482567792

# %% [markdown]
# ### Cross val

# %% [markdown]
# #### Run cross val

# %%
def baseline_score_function (y_true, y_pred):
    errors_baseline = abs(average_target - y_true)
    return np.mean(errors_baseline)

def relative_error_function (y_true, y_pred):
    errors_absolute = abs(y_pred - y_true)
    errors_relative = errors_absolute / y_true
    return np.mean(errors_relative)

def baseline_relative_error_function (y_true, y_pred):
    errors_absolute = abs(average_target - y_true)
    errors_relative = errors_absolute / y_true
    return np.mean(errors_relative)

rf = RandomForestRegressor(n_estimators = 50, n_jobs = -1)

scorer = make_scorer(baseline_score_function)
scorer2 = make_scorer(relative_error_function)
scorer3 = make_scorer(baseline_relative_error_function)

scores = cross_validate(estimator=rf, X=features, y=target, cv=10,
                        scoring = {
                            'abs': 'neg_mean_absolute_error',
                            'baseline': scorer,
                            'relative': scorer2,
                            'baseline_relative': scorer3
                        },
                        return_train_score=False, return_estimator = True)

# Use best estimator to do some visual reports
rf = scores['estimator'][0]

# %% [markdown]
# #### Cross val score

# %%
print "=== Relative"
print "RF relative abs mean: ", np.mean(np.abs(scores['test_relative']))
print "RF relative abs std: ", np.std(scores['test_relative'])

#print "Baseline: ", scores['test_baseline']
print "Baseline relative mean: ", np.mean(scores['test_baseline_relative'])
print "Baseline relative std: ", np.std(scores['test_baseline_relative'])

print "=== Absolute"

#print "Abs: ", scores['test_abs']
print "RF abs mean: ", np.mean(np.abs(scores['test_abs']))
print "RF abs std: ", np.std(scores['test_abs'])

#print "Baseline: ", scores['test_baseline']
print "Baseline mean: ", np.mean(scores['test_baseline'])
print "Baseline std: ", np.std(scores['test_baseline'])
# Out:
# === Relative
# RF relative abs mean:  0.3427287031065707
# RF relative abs std:  0.014580738776466356
# Baseline relative mean:  1.360886949914464
# Baseline relative std:  0.05294940481238444
# === Absolute
# RF abs mean:  23.162599144415967
# RF abs std:  3.0033640556153136
# Baseline mean:  59.13827533842186
# Baseline std:  5.256914794390071

# %% [markdown]
# ####  List of most important features

# %%
importance = zip(feature_list, rf.feature_importances_)
importance.sort(key=lambda x:-x[1])
pd.DataFrame(importance).head(200)
# Out:
#                                                      0         1
# 0                                                pages  0.233683
# 1                                      language_Inglês  0.195623
# 2                    category2_Inglês e Outras Línguas  0.163319
# 3                                               height  0.057446
# 4                                                width  0.040334
# 5                                              ranking  0.037681
# 6                               eigenvector_centrality  0.032462
# 7                               betweenness_centrality  0.026186
# 8                                            sha256_id  0.019416
# 9                           publisher_Cengage Learning  0.018514
# 10                                coverType_Capa comum  0.015155
# 11                                              weight  0.014512
# 12                                               depth  0.013762
# 13                                              degree  0.013154
# 14                 authors_Jerrold E. Marsden (Autor),  0.010393
# 15                    publisher_W.H. Freeman & Company  0.010364
# 16                                 coverType_Capa dura  0.008764
# 17                  authors_David J. Griffiths (Autor)  0.007655
# 18                                         reviewCount  0.003433
# 19                   authors_Dr John H. Davies (Autor)  0.002951
# 20   authors_J.M. Smith Termodinamica en ingenieria...  0.002797
# 21                     publisher_McGraw-Hill Education  0.002661
# 22                                   publisher_Pearson  0.002600
# 23                                              rating  0.002563
# 24                           publisher_Wiley-Blackwell  0.002485
# 25                       authors_David C. Lay (Autor),  0.002106
# 26                publisher_Cambridge University Press  0.001846
# 27                       authors_Phillip Kaye (Autor),  0.001830
# 28                   authors_Robert G. Bartle (Autor),  0.001620
# 29                            authors_E. Artin (Autor)  0.001607
# ..                                                 ...       ...
# 170                             publisher_Mc Graw Hill  0.000063
# 171                                  category4_Química  0.000063
# 172                                      publisher_LTC  0.000063
# 173                   authors_Rubin H. Landau (Autor),  0.000061
# 174              publisher_Addison-Wesley Professional  0.000060
# 175                authors_Daniel V. Schroeder (Autor)  0.000060
# 176                        category5_Física Matemática  0.000060
# 177                                    publisher_Vozes  0.000060
# 178                              publisher_Brooks Cole  0.000060
# 179               category2_Religião e Espiritualidade  0.000059
# 180                     authors_Jorge Nocedal (Autor),  0.000059
# 181                          publisher_Editora Forense  0.000059
# 182  category3_Educação e Desenvolvimento Profissional  0.000059
# 183                                  publisher_Saraiva  0.000058
# 184                       authors_Loring W. Tu (Autor)  0.000058
# 185                                  category2_Romance  0.000057
# 186                         publisher_Packt Publishing  0.000056
# 187                   category3_Direito Constitucional  0.000056
# 188              category6_Probabilidade e Estatística  0.000054
# 189                      authors_Dave Goldberg (Autor)  0.000054
# 190                                 category5_Dinâmica  0.000054
# 191                    authors_Larry Wasserman (Autor)  0.000054
# 192                 authors_Charles W. Misner (Autor),  0.000053
# 193                     authors_John V. Guttag (Autor)  0.000053
# 194                   authors_Martin Heidegger (Autor)  0.000053
# 195                      authors_Robert Lafore (Autor)  0.000052
# 196                publisher_Orthogonal Publishing L3C  0.000052
# 197                                    publisher_Atlas  0.000051
# 198                        authors_Ian C. Kemp (Autor)  0.000051
# 199                 authors_Alan V. Oppenheim (Autor),  0.000051
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Test dataset and visual inspection

# %%
test_predictions = rf.predict(test_features)

# %% [markdown]
# ### Predicted price vs real price

# %%
plt.figure(figsize=(8,8), dpi=130)
plt.scatter(test_target, test_predictions, 100, alpha=0.05, edgecolors="none")
baseline = [0, np.max(target)]
plt.plot(baseline, baseline, "--", color="green", label = u"Preço previsto = Preço real")
ax = plt.gca()
ax.set_ylabel(u"Preço previsto (R$)")
ax.set_xlabel(u"Preço real (R$)")
ax.legend()
plt.title(u"Preço previsto vs. Preço real")
plt.axes().set_aspect('equal', 'datalim')
#plt.xlim(0, 250)
#plt.ylim(0, 250)
plt.show()

# %% [markdown]
# ### Mean absolute error

# %% [markdown]
# Now we can compare the errors obtained by our predictions against the errors provided by the baseline (average price). Our prediction errors should be less than the baseline errors to consider the model successful.

# %%
# Calculate the absolute errors
errors = abs(test_predictions - test_target)
errors_baseline = abs(average_target - test_target)
errors_relative = errors/test_target
errors_baseline_relative = errors_baseline/test_target
# Print out the mean absolute error (mae)
print "== Absolute"
print('Mean absolute prediction error: R$', round(np.mean(errors), 2))
print('Std prediction error: R$', round(np.std(errors), 2))
print('Mean absolute error using average: R$', round(np.mean(errors_baseline), 2))
print('Std prediction error using average: R$', round(np.std(errors_baseline), 2))
print "== Relative"
print('Mean relative absolute prediction error: ', round(np.mean(errors_relative), 2))
print('Std relative prediction error: ', round(np.std(errors_relative), 2))
print('Mean relative absolute error using average: ', round(np.mean(errors_baseline_relative), 2))
print('Std relative prediction error using average: ', round(np.std(errors_baseline_relative), 2))
# Out:
# == Absolute
# ('Mean absolute prediction error: R$', 22.67)
# ('Std prediction error: R$', 77.19)
# ('Mean absolute error using average: R$', 56.53)
# ('Std prediction error using average: R$', 135.21)
# == Relative
# ('Mean relative absolute prediction error: ', 0.34)
# ('Std relative prediction error: ', 0.49)
# ('Mean relative absolute error using average: ', 1.34)
# ('Std relative prediction error using average: ', 1.54)

# %% [markdown]
# ### Join data

# %% [markdown]
# Below we can inspect the rows with the biggest prediction error.

# %%
pd.set_option('display.max_columns', None)
data = {
    "all_features": test_features.tolist(),
    "sha256_id": test_features[:, 0],
    "target": test_target,
    "prediction": test_predictions,
    "error": errors,
    "error_relative": errors_relative,
    "error_baseline": errors_baseline,
    "error_baseline_relative": errors_baseline_relative
}
predicted_df = pd.DataFrame(data = data)
joined_predicted_df = predicted_df
joined_predicted_df = predicted_df.set_index("sha256_id").join(df.set_index("sha256_id"))

# %% [markdown]
# ### Worst absolute predictions

# %%
joined_predicted_df.sort_values('error', ascending = False).head(20)
# Out:
#                                                    all_features      error  \
# sha256_id
# 4.565469e+08  [456546893.0, 40.0, 2.15307124936e-06, 0.00107...  2121.6850
# 2.866815e+09  [2866815273.0, 81.0, 8.42631499454e-06, 0.0020...   874.4600
# 2.300254e+09  [2300254391.0, 24.0, 5.685649294e-07, 0.001574...   754.0148
# 1.129271e+09  [1129270548.0, 1.0, 3.73316544747e-08, 0.0, 36...   713.1688
# 1.378771e+09  [1378771352.0, 23.0, 9.01769619103e-07, 0.0008...   664.8652
# 8.325317e+08  [832531727.0, 46.0, 3.14766304933e-06, 0.00139...   622.1542
# 2.187742e+09  [2187741581.0, 19.0, 6.01564690239e-07, 0.0005...   614.9628
# 2.308676e+09  [2308676145.0, 22.0, 2.05497353151e-07, 0.0004...   548.4416
# 1.879984e+09  [1879983517.0, 43.0, 9.90680374449e-06, 0.0023...   520.2062
# 3.462654e+09  [3462654472.0, 6.0, 3.30703168506e-07, 0.00017...   483.5850
# 1.961298e+09  [1961298192.0, 25.0, 3.21227939388e-06, 0.0007...   426.4694
# 3.374043e+09  [3374042526.0, 4.0, 2.3384209771e-06, 0.000126...   397.1264
# 3.040507e+09  [3040506514.0, 20.0, 8.67846344918e-07, 0.0006...   393.0994
# 2.904504e+09  [2904504457.0, 21.0, 1.1506720205e-06, 0.00101...   384.4428
# 4.495775e+08  [449577459.0, 13.0, 1.31887490446e-06, 0.00046...   368.6410
# 2.471143e+09  [2471143358.0, 21.0, 8.02837287192e-06, 0.0025...   362.4336
# 2.902414e+09  [2902414236.0, 57.0, 5.23282227763e-06, 0.0015...   361.5746
# 1.196648e+09  [1196648472.0, 2.0, 8.80436404849e-08, 6.68885...   341.9374
# 1.623173e+09  [1623172789.0, 18.0, 1.93546568832e-05, 0.0006...   325.1182
# 2.187742e+09                                 Wiley      NaN
# 2.308676e+09              University Science Books      NaN
# 1.879984e+09                           Basic Books      NaN
# 3.462654e+09                       Morgan Kaufmann      NaN
# 1.961298e+09               Dover Publications Inc.      NaN
# 3.374043e+09                             CRC Press      NaN
# 3.040507e+09                         Prentice Hall      NaN
# 2.904504e+09                     John Wiley & Sons      NaN
# 4.495775e+08            Cambridge University Press      NaN
# 2.471143e+09                               OUP USA      NaN
# 2.902414e+09                        Westview Press      NaN
# 1.196648e+09                    Wiley-Interscience      NaN
# 1.623173e+09                      Simon & Schuster      NaN
# 4.161038e+09                           Basic Books      NaN
#
#                      publicationDate rankingCategory category1  \
# sha256_id
# 4.565469e+08                     NaN             NaN       NaN
# 2.866815e+09                     NaN          Livros    Livros
# 2.300254e+09                     NaN          Livros    Livros
# 1.129271e+09                     NaN             NaN       NaN
# 1.378771e+09                     NaN             NaN       NaN
# 8.325317e+08                     NaN             NaN       NaN
# 2.187742e+09                     NaN          Livros    Livros
# 2.308676e+09                     NaN          Livros    Livros
# 1.879984e+09                     NaN          Livros    Livros
# 3.462654e+09                     NaN             NaN       NaN
# 1.961298e+09                     NaN             NaN       NaN
# 3.374043e+09                     NaN             NaN       NaN
# 3.040507e+09                     NaN          Livros    Livros
# 2.904504e+09                     NaN          Livros    Livros
# 4.495775e+08    6 de outubro de 2017             NaN       NaN
# 2.471143e+09  24 de novembro de 2016             NaN       NaN
# 2.902414e+09                     NaN          Livros    Livros
# 1.196648e+09                     NaN          Livros    Livros
# 1.623173e+09    14 de agosto de 2018             NaN       NaN
# 4.161038e+09   8 de setembro de 2015          Livros    Livros
#
#                             category2                category3  \
# sha256_id
# 4.565469e+08                      NaN                      NaN
# 2.866815e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 2.300254e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 1.129271e+09                      NaN                      NaN
# 1.378771e+09                      NaN                      NaN
# 8.325317e+08                      NaN                      NaN
# 2.187742e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 2.308676e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 1.879984e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 3.462654e+09                      NaN                      NaN
# 1.961298e+09                      NaN                      NaN
# 3.374043e+09                      NaN                      NaN
# 3.040507e+09  Inglês e Outras Línguas  Engenharia e Transporte
# 2.904504e+09  Inglês e Outras Línguas  Engenharia e Transporte
# 4.495775e+08                      NaN                      NaN
# 2.471143e+09                      NaN                      NaN
# 2.902414e+09  Inglês e Outras Línguas    Ciências Tecnológicas
# 1.196648e+09  Inglês e Outras Línguas  Engenharia e Transporte
# 1.623173e+09                      NaN                      NaN
# 4.161038e+09  Inglês e Outras Línguas    Ciências Tecnológicas
#
#                         category4              category5  \
# sha256_id
# 4.565469e+08                  NaN                    NaN
# 2.866815e+09               Física      Física Matemática
# 2.300254e+09  Ciências Biológicas             Bioquímica
# 1.129271e+09                  NaN                    NaN
# 1.378771e+09                  NaN                    NaN
# 8.325317e+08                  NaN                    NaN
# 2.187742e+09           Matemática               Aplicada
# 2.308676e+09              Química       Física e Teórica
# 1.879984e+09           Matemática        Estudo e Ensino
# 3.462654e+09                  NaN                    NaN
# 1.961298e+09                  NaN                    NaN
# 3.374043e+09                  NaN                    NaN
# 3.040507e+09           Engenharia  Elétrica e Eletrônica
# 2.904504e+09           Engenharia       Telecomunicações
# 4.495775e+08                  NaN                    NaN
# 2.471143e+09                  NaN                    NaN
# 2.902414e+09           Matemática  Geometria e Topologia
# 1.196648e+09           Engenharia  Ciência dos Materiais
# 1.623173e+09                  NaN                    NaN
# 4.161038e+09           Matemática        Estudo e Ensino
#
#                           category6 category7  category8  category9  \
# sha256_id
# 4.565469e+08                    NaN       NaN        NaN        NaN
# 2.866815e+09                    NaN       NaN        NaN        NaN
# 2.300254e+09                    NaN       NaN        NaN        NaN
# 1.129271e+09                    NaN       NaN        NaN        NaN
# 1.378771e+09                    NaN       NaN        NaN        NaN
# 8.325317e+08                    NaN       NaN        NaN        NaN
# 2.187742e+09                    NaN       NaN        NaN        NaN
# 2.308676e+09                    NaN       NaN        NaN        NaN
# 1.879984e+09                    NaN       NaN        NaN        NaN
# 3.462654e+09                    NaN       NaN        NaN        NaN
# 1.961298e+09                    NaN       NaN        NaN        NaN
# 3.374043e+09                    NaN       NaN        NaN        NaN
# 3.040507e+09        Desenho Digital       NaN        NaN        NaN
# 2.904504e+09             Microondas       NaN        NaN        NaN
# 4.495775e+08                    NaN       NaN        NaN        NaN
# 2.471143e+09                    NaN       NaN        NaN        NaN
# 2.902414e+09  Geometria Diferencial       NaN        NaN        NaN
# 1.196648e+09                    NaN       NaN        NaN        NaN
# 1.623173e+09                    NaN       NaN        NaN        NaN
# 4.161038e+09                    NaN       NaN        NaN        NaN
#
#               category10      isbn10          isbn13 language  postProcessed  \
# sha256_id
# 4.565469e+08         NaN  0070006571  978-0070006577   Inglês              1
# 2.866815e+09         NaN  0471198269  978-0471198260   Inglês              1
# 2.300254e+09         NaN  1464126119  978-1464126116   Inglês              1
# 1.129271e+09         NaN  1285195698  978-1285195698   Inglês              1
# 1.378771e+09         NaN  0133356817  978-0133356816   Inglês              1
# 8.325317e+08         NaN  0471317160  978-0471317166   Inglês              1
# 2.187742e+09         NaN  0470458364  978-0470458365   Inglês              1
# 2.308676e+09         NaN  0935702431  978-0935702439   Inglês              1
# 1.879984e+09         NaN  0465053734  978-0465053735   Inglês              1
# 3.462654e+09         NaN  0128119055  978-0128119051   Inglês              1
# 1.961298e+09         NaN  0486795640  978-0486795645   Inglês              1
# 3.374043e+09         NaN  1138429619  978-1138429611   Inglês              1
# 3.040507e+09         NaN  0131873741  978-0131873742   Inglês              1
# 2.904504e+09         NaN  0470631554  978-0470631553   Inglês              1
# 4.495775e+08         NaN  1108407846  978-1108407847   Inglês              1
# 2.471143e+09         NaN  0190602384  978-0190602383   Inglês              1
# 2.902414e+09         NaN  0201315963  978-0201315967   Inglês              1
# 1.196648e+09         NaN  0471246891  978-0471246893   Inglês              1
# 1.623173e+09         NaN  1476776628  978-1476776620   Inglês              1
# 3.766802e+09      NaN                      NaN          Livros    Livros
# 2.668220e+09      NaN  20 de fevereiro de 2013          Livros    Livros
# 2.814283e+09      NaN                      NaN             NaN       NaN
# 3.275789e+09      NaN                      NaN          Livros    Livros
# 2.591816e+09      NaN                      NaN          Livros    Livros
# 7.776154e+08      NaN                      NaN             NaN       NaN
# 2.860938e+09      NaN                      NaN          Livros    Livros
# 2.820914e+09      NaN    24 de janeiro de 2017             NaN       NaN
# 1.623173e+09      NaN     14 de agosto de 2018             NaN       NaN
# 1.727980e+09      NaN                      NaN          Livros    Livros
# 1.961298e+09      NaN                      NaN             NaN       NaN
# 4.057502e+08      NaN                      NaN          Livros    Livros
# 1.162831e+09      NaN     15 de agosto de 2005          Livros    Livros
#
#                                        category2  \
# sha256_id
# 2.764867e+09                             Romance
# 1.879984e+09             Inglês e Outras Línguas
# 1.488834e+09  Administração, Negócios e Economia
# 1.011804e+09                                 NaN
# 4.134595e+09                 Literatura e Ficção
# 4.161038e+09             Inglês e Outras Línguas
# 1.150685e+09           Arte, Cinema e Fotografia
# 3.766802e+09        Biografias e Histórias Reais
# 2.668220e+09                             Romance
# 2.814283e+09                                 NaN
# 3.275789e+09             Inglês e Outras Línguas
# 2.591816e+09                             Romance
# 7.776154e+08                                 NaN
# 2.860938e+09        Biografias e Histórias Reais
# 2.820914e+09                                 NaN
# 1.623173e+09                                 NaN
# 1.727980e+09        HQs, Mangás e Graphic Novels
# 1.961298e+09                                 NaN
# 4.057502e+08             Inglês e Outras Línguas
# 1.162831e+09             Inglês e Outras Línguas
#
#                                  category3                   category4  \
# sha256_id
# 2.764867e+09                           NaN                         NaN
# 1.879984e+09         Ciências Tecnológicas                  Matemática
# 1.488834e+09                     Carreiras                         NaN
# 1.011804e+09                           NaN                         NaN
# 4.134595e+09                           NaN                         NaN
# 4.161038e+09         Ciências Tecnológicas                  Matemática
# 1.150685e+09                          Arte                    Pinturas
# 3.766802e+09                           NaN                         NaN
# 2.668220e+09                           NaN                         NaN
# 2.814283e+09                           NaN                         NaN
# 3.275789e+09     Infantil e Infantojuvenil                    De 4 a 8
# 2.591816e+09                           NaN                         NaN
# 7.776154e+08                           NaN                         NaN
# 2.860938e+09                           NaN                         NaN
# 2.820914e+09                           NaN                         NaN
# 1.623173e+09                           NaN                         NaN
# 1.727980e+09                Graphic Novels                         NaN
# 1.961298e+09                           NaN                         NaN
# 4.057502e+08  Biografias e Histórias Reais  Líderes e Pessoas Notáveis
# 1.162831e+09       Engenharia e Transporte                  Engenharia
#
#                     category5   category6 category7  category8  category9  \
# sha256_id
# 2.764867e+09              NaN         NaN       NaN        NaN        NaN
# 1.879984e+09  Estudo e Ensino         NaN       NaN        NaN        NaN
# 1.488834e+09              NaN         NaN       NaN        NaN        NaN
# 1.011804e+09              NaN         NaN       NaN        NaN        NaN
# 4.134595e+09              NaN         NaN       NaN        NaN        NaN
# 4.161038e+09  Estudo e Ensino         NaN       NaN        NaN        NaN
# 1.150685e+09              NaN         NaN       NaN        NaN        NaN
# 1.659269e+09                 Wolff Francis (Autor)  Capa comum
# 2.343084e+09                Lauro Trevisan (Autor)  Capa comum
# 3.758766e+08                  Walter Fraga (Autor)  Capa comum
# 1.814106e+09              Joseph Ratzinger (Autor)  Capa comum
# 6.994888e+08                   Susan David (Autor)  Capa comum
# 5.720705e+08            Mortimer J. Adler (Autor),  Capa comum
# 2.634093e+09                  Hill Nathan (Autor),  Capa comum
# 6.640752e+08                 Marcel Cohen (Autor),  Capa comum
# 1.201608e+09  Jean Marcel Carvalho França (Autor),  Capa comum
# 1.048610e+09             Jorge Luis Borges (Autor)  Capa comum
# 1.729692e+09                      Sam Kean (Autor)  Capa comum
# 1.739217e+09                 Arthur Winter (Autor)  Capa comum
# 4.129687e+09            Yuval Noah Harari (Autor),  Capa comum
# 1.420364e+09                   Philip Roth (Autor)  Capa comum
# 2.149309e+09               Vários Autores (Autor),  Capa comum
# 4.281332e+09               Wilhelm Dilthey (Autor)  Capa comum
# 3.384746e+09              Giorgio Agamben (Autor),  Capa comum
# 1.851555e+09        Maurice Merleau-Ponty (Autor),  Capa comum
# 3.922724e+09                Henri Lefebvre (Autor)  Capa comum
# 1.196681e+09    Katarzyna de Lazari-Radek (Autor),  Capa comum
#
#                            publisher  edition      publicationDate  \
# sha256_id
# 1.659269e+09                   UNESP      NaN                  NaN
# 2.343084e+09                Da Mente      NaN                  NaN
# 3.758766e+08  Civilização Brasileira      NaN                  NaN
# 1.814106e+09                 Planeta      NaN                  NaN
# 6.994888e+08                 Cultrix      NaN                  NaN
# 5.720705e+08           É Realizações      NaN                  NaN
# 2.634093e+09              Intrínseca      NaN                  NaN
# 6.640752e+08              Editora 34      NaN                  NaN
# 1.201608e+09                   Globo      NaN                  NaN
# 1.048610e+09    Companhia das Letras      NaN                  NaN
# 1.729692e+09                   Zahar      NaN                  NaN
# 1.739217e+09              Alta Books      NaN                  NaN
# 4.129687e+09                    L&PM      NaN                  NaN
# 1.420364e+09      Companhia de Bolso      NaN                  NaN
# 2.149309e+09              Editora 34      NaN                  NaN
# 4.281332e+09   Forense Universitária      NaN                  NaN
# 3.384746e+09  Civilização Brasileira      NaN                  NaN
# 1.851555e+09               Autêntica      NaN                  NaN
# 3.922724e+09                    L&PM      NaN                  NaN
# 1.196681e+09              OUP Oxford      NaN  27 de julho de 2017
#
#              rankingCategory category1  \
# sha256_id
# 1.659269e+09          Livros    Livros
# 2.343084e+09          Livros    Livros
# 3.758766e+08          Livros    Livros
# 1.814106e+09          Livros    Livros
# 6.994888e+08          Livros    Livros
# 5.720705e+08          Livros    Livros
# 2.634093e+09          Livros    Livros
# 6.640752e+08          Livros    Livros
# 1.201608e+09          Livros    Livros
# 1.048610e+09          Livros    Livros
# 1.729692e+09          Livros    Livros
# 1.739217e+09          Livros    Livros
# 4.129687e+09          Livros    Livros
# 1.420364e+09          Livros    Livros
# 2.149309e+09          Livros    Livros
# 4.281332e+09          Livros    Livros
# 3.384746e+09          Livros    Livros
# 1.851555e+09          Livros    Livros
# 3.922724e+09          Livros    Livros
# 1.196681e+09          Livros    Livros
#
#                                            category2  \
# sha256_id
# 1.659269e+09  Política, Filosofia e Ciências Sociais
# 2.343084e+09                               Autoajuda
# 3.758766e+08                                História
# 1.814106e+09              Religião e Espiritualidade
# 6.994888e+08                         Saúde e Família
# 5.720705e+08        Educação, Referência e Didáticos
# 2.634093e+09                                 Romance
# 6.640752e+08            Biografias e Histórias Reais
# 1.201608e+09                                História
# 1.048610e+09                     Literatura e Ficção
# 1.729692e+09                                Ciências
# 1.739217e+09                                Ciências
# 4.129687e+09                                História
# 1.420364e+09                     Literatura e Ficção
# 2.149309e+09                     Literatura e Ficção
# 4.281332e+09  Política, Filosofia e Ciências Sociais
# 3.384746e+09  Política, Filosofia e Ciências Sociais
# 1.851555e+09  Política, Filosofia e Ciências Sociais
# 3.922724e+09  Política, Filosofia e Ciências Sociais
# 1.196681e+09                 Inglês e Outras Línguas
#
#                                            category3           category4  \
# sha256_id
# 1.659269e+09                               Filosofia                 NaN
# 2.343084e+09                              Autoestima                 NaN
# 3.758766e+08                                     NaN                 NaN
# 1.814106e+09                             Cristandade         Catolicismo
# 6.994888e+08             Psicologia e Aconselhamento           Cognitiva
# 5.720705e+08                        Escolas e Ensino  Teoria da Educação
# 2.634093e+09                                     NaN                 NaN
# 6.640752e+08                                     NaN                 NaN
# 1.201608e+09                                Américas      América Latina
# 1.048610e+09              Teoria e Crítica Literária                 NaN
# 1.729692e+09                                 Química                 NaN
# 1.739217e+09                                 Química                 NaN
# 4.129687e+09                                     NaN                 NaN
# 1.420364e+09                                  Ficção                 NaN
# 2.149309e+09                                     NaN                 NaN
# 4.281332e+09                               Filosofia                 NaN
# 3.384746e+09                               Filosofia                 NaN
# 1.851555e+09                               Filosofia                 NaN
# 3.922724e+09                               Filosofia                 NaN
# 1.196681e+09  Política, Filosofia e Ciências Sociais           Filosofia
#
#                         category5 category6 category7  category8  category9  \
# sha256_id
# 1.659269e+09                  NaN       NaN       NaN        NaN        NaN
# 2.343084e+09                  NaN       NaN       NaN        NaN        NaN
# 3.758766e+08                  NaN       NaN       NaN        NaN        NaN
# 1.814106e+09                  NaN       NaN       NaN        NaN        NaN
# 6.994888e+08                  NaN       NaN       NaN        NaN        NaN
# 5.720705e+08  Educação Não-Formal       NaN       NaN        NaN        NaN
# 2.634093e+09                  NaN       NaN       NaN        NaN        NaN
# 6.640752e+08                  NaN       NaN       NaN        NaN        NaN
# 1.201608e+09       América do Sul       NaN       NaN        NaN        NaN
# 1.048610e+09                  NaN       NaN       NaN        NaN        NaN
# 1.729692e+09                  NaN       NaN       NaN        NaN        NaN
# 1.739217e+09                  NaN       NaN       NaN        NaN        NaN
# 4.129687e+09                  NaN       NaN       NaN        NaN        NaN
# 1.420364e+09                  NaN       NaN       NaN        NaN        NaN
# 2.149309e+09                  NaN       NaN       NaN        NaN        NaN
# 4.281332e+09                  NaN       NaN       NaN        NaN        NaN
# 3.384746e+09                  NaN       NaN       NaN        NaN        NaN
# 1.851555e+09                  NaN       NaN       NaN        NaN        NaN
# 3.922724e+09                Henri Lefebvre (Autor)  Capa comum
# 1.196681e+09    Katarzyna de Lazari-Radek (Autor),  Capa comum
#
#                            publisher  edition      publicationDate  \
# sha256_id
# 1.659269e+09                   UNESP      NaN                  NaN
# 2.343084e+09                Da Mente      NaN                  NaN
# 3.758766e+08  Civilização Brasileira      NaN                  NaN
# 1.814106e+09                 Planeta      NaN                  NaN
# 6.994888e+08                 Cultrix      NaN                  NaN
# 5.720705e+08           É Realizações      NaN                  NaN
# 2.634093e+09              Intrínseca      NaN                  NaN
# 6.640752e+08              Editora 34      NaN                  NaN
# 1.201608e+09                   Globo      NaN                  NaN
# 1.048610e+09    Companhia das Letras      NaN                  NaN
# 1.729692e+09                   Zahar      NaN                  NaN
# 1.739217e+09              Alta Books      NaN                  NaN
# 4.129687e+09                    L&PM      NaN                  NaN
# 1.420364e+09      Companhia de Bolso      NaN                  NaN
# 2.149309e+09              Editora 34      NaN                  NaN
# 4.281332e+09   Forense Universitária      NaN                  NaN
# 3.384746e+09  Civilização Brasileira      NaN                  NaN
# 1.851555e+09               Autêntica      NaN                  NaN
# 3.922724e+09                    L&PM      NaN                  NaN
# 1.196681e+09              OUP Oxford      NaN  27 de julho de 2017
#
#              rankingCategory category1  \
# sha256_id
# 1.659269e+09          Livros    Livros
# 2.343084e+09          Livros    Livros
# 3.758766e+08          Livros    Livros
# 1.814106e+09          Livros    Livros
# 6.994888e+08          Livros    Livros
# 5.720705e+08          Livros    Livros
# 2.634093e+09          Livros    Livros
# 6.640752e+08          Livros    Livros
# 1.201608e+09          Livros    Livros
# 1.048610e+09          Livros    Livros
# 1.729692e+09          Livros    Livros
# 1.739217e+09          Livros    Livros
# 4.129687e+09          Livros    Livros
# 1.420364e+09          Livros    Livros
# 2.149309e+09          Livros    Livros
# 4.281332e+09          Livros    Livros
# 3.384746e+09          Livros    Livros
# 1.851555e+09          Livros    Livros
# 3.922724e+09          Livros    Livros
# 1.196681e+09          Livros    Livros
#
#                                            category2  \
# sha256_id
# 1.659269e+09  Política, Filosofia e Ciências Sociais
# 2.343084e+09                               Autoajuda
# 3.758766e+08                                História
# 1.814106e+09              Religião e Espiritualidade
# 6.994888e+08                         Saúde e Família
# 5.720705e+08        Educação, Referência e Didáticos
# 2.634093e+09                                 Romance
# 6.640752e+08            Biografias e Histórias Reais
# 1.201608e+09                                História
# 1.048610e+09                     Literatura e Ficção
# 1.729692e+09                                Ciências
# 1.739217e+09                                Ciências
# 4.129687e+09                                História
# 1.420364e+09                     Literatura e Ficção
# 2.149309e+09                     Literatura e Ficção
# 4.281332e+09  Política, Filosofia e Ciências Sociais
# 3.384746e+09  Política, Filosofia e Ciências Sociais
# 1.851555e+09  Política, Filosofia e Ciências Sociais
# 3.922724e+09  Política, Filosofia e Ciências Sociais
# 1.196681e+09                 Inglês e Outras Línguas
#
#                                            category3           category4  \
# sha256_id
# 1.659269e+09                               Filosofia                 NaN
# 2.343084e+09                              Autoestima                 NaN
# 3.758766e+08                                     NaN                 NaN
# 1.814106e+09                             Cristandade         Catolicismo
# 6.994888e+08             Psicologia e Aconselhamento           Cognitiva
# 5.720705e+08                        Escolas e Ensino  Teoria da Educação
# 2.634093e+09                                     NaN                 NaN
# 6.640752e+08                                     NaN                 NaN
# 1.201608e+09                                Américas      América Latina
# 1.048610e+09              Teoria e Crítica Literária                 NaN
# 1.729692e+09                                 Química                 NaN
# 1.739217e+09                                 Química                 NaN
# 4.129687e+09                                     NaN                 NaN
# 1.420364e+09                                  Ficção                 NaN
# 2.149309e+09                                     NaN                 NaN
# 4.281332e+09                               Filosofia                 NaN
# 3.384746e+09                               Filosofia                 NaN
# 1.851555e+09                               Filosofia                 NaN
# 3.922724e+09                               Filosofia                 NaN
# 1.196681e+09  Política, Filosofia e Ciências Sociais           Filosofia
#
#                         category5 category6 category7  category8  category9  \
# sha256_id
# 1.659269e+09                  NaN       NaN       NaN        NaN        NaN
# 2.343084e+09                  NaN       NaN       NaN        NaN        NaN
# 3.758766e+08                  NaN       NaN       NaN        NaN        NaN
# 1.814106e+09                  NaN       NaN       NaN        NaN        NaN
# 6.994888e+08                  NaN       NaN       NaN        NaN        NaN
# 5.720705e+08  Educação Não-Formal       NaN       NaN        NaN        NaN
# 2.634093e+09                  NaN       NaN       NaN        NaN        NaN
# 6.640752e+08                  NaN       NaN       NaN        NaN        NaN
# 1.201608e+09       América do Sul       NaN       NaN        NaN        NaN
# 1.048610e+09                  NaN       NaN       NaN        NaN        NaN
# 1.729692e+09                  NaN       NaN       NaN        NaN        NaN
# 1.739217e+09                  NaN       NaN       NaN        NaN        NaN
# 4.129687e+09                  NaN       NaN       NaN        NaN        NaN
# 1.420364e+09                  NaN       NaN       NaN        NaN        NaN
# 2.149309e+09                  NaN       NaN       NaN        NaN        NaN
# 4.281332e+09                  NaN       NaN       NaN        NaN        NaN
# 3.384746e+09                  NaN       NaN       NaN        NaN        NaN
# 1.851555e+09                  NaN       NaN       NaN        NaN        NaN
# 3.922724e+09                  NaN       NaN       NaN        NaN        NaN
# 1.196681e+09   História e Estudos       NaN       NaN        NaN        NaN
#
#               category10      isbn10          isbn13   language  \
# sha256_id
# 1.659269e+09         NaN  8539303701  978-8539303700  Português
# 2.343084e+09         NaN  8571510059  978-8571510050  Português
# 3.758766e+08         NaN  8520010911  978-8520010914  Português
# 1.814106e+09         NaN  8542208390  978-8542208399  Português
# 6.994888e+08         NaN  8531614503  978-8531614507  Português
# 5.720705e+08         NaN  8580331420  978-8580331424  Português
# 2.634093e+09         NaN  8551003100  978-8551003107  Português
# 6.640752e+08         NaN  8573266546  978-8573266542  Português
# 1.201608e+09         NaN  8525058270  978-8525058270  Português
# 1.048610e+09         NaN  8535922423  978-8535922424  Português
# 1.729692e+09         NaN  8537806935  978-8537806937  Português
# 1.739217e+09         NaN  8576085267  978-8576085263  Português
# 4.129687e+09         NaN  8525432180  978-8525432186  Português
# 1.420364e+09         NaN  8535929207  978-8535929201  Português
# 2.149309e+09         NaN  8573266759  978-8573266757  Português
# 4.281332e+09         NaN  8521804709  978-8521804703  Português
# 1.196681e+09   10.9    17.0    0.8   141.0                0.000012      39
#
#               betweenness_centrality
# sha256_id
# 1.659269e+09                0.002460
# 2.343084e+09                0.000064
# 3.758766e+08                0.000730
# 1.814106e+09                0.004480
# 6.994888e+08                0.001076
# 5.720705e+08                0.000476
# 2.634093e+09                0.003352
# 6.640752e+08                0.000439
# 1.201608e+09                0.001132
# 1.048610e+09                0.000125
# 1.729692e+09                0.001932
# 1.739217e+09                0.000901
# 4.129687e+09                0.008301
# 1.420364e+09                0.000815
# 2.149309e+09                0.000898
# 4.281332e+09                0.000064
# 3.384746e+09                0.003240
# 1.851555e+09                0.002130
# 3.922724e+09                0.000172
# 1.196681e+09                0.000950

# %% [markdown]
# ### Relative errors distribution

# %%
count = len(predicted_df.error_relative)
hist_predicted = np.histogram(predicted_df.error_relative, np.linspace(0, 2, 20))
hist_baseline = np.histogram(predicted_df.error_baseline_relative, np.linspace(0, 2, 20))
centers = np.convolve(hist_predicted[1], [0.5, 0.5])
centers = centers[1:-1]
plt.bar(centers, hist_predicted[0]/count, width=(centers[1]-centers[0])*0.95)
ylim = max(hist_predicted[0]/count) * 1.1
plt.ylim(0, ylim)
plt.show()
plt.bar(centers, hist_baseline[0]/count, width=(centers[1]-centers[0])*0.95)
plt.ylim(0, ylim)
plt.show()

# %% [markdown]
# ### Joined data summary

# %%
predicted_df.describe(percentiles=[0.25, 0.5, 0.75, 0.85, 0.9, 0.95, 0.99])
# Out:
#              error  error_baseline  error_baseline_relative  error_relative  \
# count  1807.000000     1807.000000              1807.000000     1807.000000
# mean     22.668701       56.527253                 1.338571        0.342375
# std      77.207045      135.247663                 1.536236        0.491433
# min       0.017800        0.035448                 0.000488        0.000385
# 25%       3.657300       24.915000                 0.415800        0.094978
# 50%       8.576400       39.225448                 0.869292        0.201402
# 75%      16.993200       51.265448                 1.703177        0.387908
# 85%      25.435180       57.125448                 2.465782        0.562857
# 90%      37.116880       62.082910                 3.041993        0.698932
# 95%      68.542280      113.563552                 4.196559        1.136984
# 99%     324.970000      551.267552                 7.062428        2.763904
# max    2121.685000     2458.354552                23.238483        5.162172
#
#         prediction     sha256_id       target
# count  1807.000000  1.807000e+03  1807.000000
# mean     68.392427  2.082974e+09    70.150487
# std     113.877517  1.229898e+09   146.568916
# min      11.848400  7.920160e+05     3.000000
# 25%      30.241500  1.003560e+09    26.900000
# 50%      39.477600  2.044128e+09    39.800000
# 75%      61.243400  3.116815e+09    62.465000
# 85%      88.574340  3.597942e+09    88.960000
# 90%     115.092240  3.799407e+09   115.840000
# 95%     179.189520  4.057554e+09   186.279000
# 99%     621.835024  4.248119e+09   623.983000
# max    1601.926800  4.294367e+09  2531.070000

# %% [markdown]
# ### Visualize decision tree

# %%
# Pull out one tree from the forest
tree = rf.estimators_[0]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot',
                feature_names = feature_list, rounded = True)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')

# %% [markdown]
# <img src="files/image.png">
