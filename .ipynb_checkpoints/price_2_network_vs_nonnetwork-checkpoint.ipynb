# %% [markdown]
# # Amazon Copurchased

# %% [markdown]
# This is a Python notebook created using "jupyter".
#
# Author: Rafael J. P. dos Santos

# %% [markdown]
# ## Parameters

# %% [markdown]
# We use the parameter below to set the maximum number of edges to be read from the CSV containing edges (links).

# %%
max_edges = 15000 # Set quantity to read from file
edges_csv_file = "data/20180812_links"
nodes_csv_file = "data/20180812_nodes"

# %% [markdown]
# ## Load the libraries

# %% [markdown]
# Let's load the Python libraries that we will need throughout the script

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import export_graphviz
import pydot
from sklearn.ensemble import RandomForestRegressor
from __future__ import division

# %% [markdown]
# ## Read graph

# %% [markdown]
# ### Read only first lines of datafile

# %% [markdown]
# Due to slowness in calculating centrality measures, we use the parameter provided in the beggining of the script to limit the number of edges we will read.

# %%
lines = []
total_line_count = 0
with open(edges_csv_file, 'rb') as f:
    f.readline()   # skip first line / header
    while True:
        line = f.readline()
        if not line:
            break
        if not (max_edges > 0 and len(lines) >= max_edges):
            lines.append(line)
        total_line_count += 1
G = nx.parse_edgelist(lines, delimiter=',', nodetype=int)

# %%
print "Using %d edges out of %d available (%.2f%% of data)" % (len(lines), total_line_count, len(lines)/total_line_count * 100)
# Out:
# Using 15000 edges out of 229338 available (6.54% of data)

# %% [markdown]
# ### Calculate nodes centrality measures

# %% [markdown]
# Now that we have our NetworkX graph, let's calculate some centrality measures for every node.

# %%
centrality_measures = {}

# %% [markdown]
# #### Degree

# %%
centrality_measures["degree"] = nx.degree(G)

# %% [markdown]
# #### Eigenvector centrality

# %%
centrality_measures["eigenvector_centrality"] = nx.eigenvector_centrality_numpy(G)

# %% [markdown]
# ####  Approximate betweenness centrality (current flow)

# %%
centrality_measures["betweenness_centrality"] = nx.approximate_current_flow_betweenness_centrality(G)

# %% [markdown]
# #### Closeness centrality

# %%
# Very slow!
centrality_measures["closeness_centrality"] = nx.closeness_centrality(G)

# %% [markdown]
# #### Betweenness centrality

# %%
# Very slow!
centrality_measures["betweenness_centrality"] = nx.betweenness_centrality(G)

# %% [markdown]
# ### Load node properties

# %% [markdown]
# Let's load the CSV containing the nodes data (title, price) into a Pandas dataframe, and append the centrality measures calculated above.

# %%
df = pd.read_csv(nodes_csv_file)

# %%
# Add columns to dataframe
def merge_columns(dataframe, data):
    df = dataframe.copy()
    for col in data:
        rows = []
        for item in data[col].items():
            rows.append({"id": item[0], col: item[1]})
        df = df.merge(pd.DataFrame(rows))
    return df

df = merge_columns(df, centrality_measures)

# %% [markdown]
# ### Let's convert some fields to numeric

# %%
categorical_features = [
    'category1',
    'category2',
    'category3',
    'category4',
    'category5',
    'category6',
    'category7',
    'category8',
    'category9',
    'category10',
    'language',
    'coverType',
    'publisher',
    'rankingCategory'
]

numeric_features = [
    'degree',
    'eigenvector_centrality',
    #'closeness_centrality',
    'betweenness_centrality',
    'ranking',
    'reviewCount',
    'pages',
    'weight',
    'height',
    'width',
    'depth',
    'rating'
]

df = df.replace("<<MISSING_DATA>>", np.NaN)
df[numeric_features] = df[numeric_features].apply(pd.to_numeric)
df[['price']] = df[['price']].apply(pd.to_numeric)

for feature in numeric_features:
    df[feature].fillna(df[feature].mean(), inplace = True)

# %% [markdown]
# ### Remove nodes without price and outliers

# %%
df = df.drop(df[df["price"].isnull()].index)
#df = df.drop(df[df["price"] > 500].index)

# %% [markdown]
# ### Inspect columns

# %%
df.columns
# Out:
# Index([u'id', u'title', u'url', u'authors', u'coverType', u'publisher',
#        u'edition', u'publicationDate', u'rankingCategory', u'category1',
#        u'category2', u'category3', u'category4', u'category5', u'category6',
#        u'category7', u'category8', u'category9', u'category10', u'isbn10',
#        u'isbn13', u'language', u'postProcessed', u'price', u'ranking',
#        u'pages', u'reviewCount', u'rating', u'width', u'height', u'depth',
#        u'weight', u'eigenvector_centrality', u'degree',
#        u'betweenness_centrality'],
#       dtype='object')

# %% [markdown]
# ### Features summary

# %% [markdown]
# Below we have a summary of the Pandas dataframe. We can see the number of nodes that we are actually analyzing, which depends on the max_edges parameter defined before.

# %%
df.describe(include='all')
# Out:
#                  id          title                                       url  \
# count   3206.000000           3206                                      3206
# unique          NaN           3148                                      3206
# top             NaN  Macroeconomia  https://www.amazon.com.br/dp/8535931015/
# freq            NaN              5                                         1
# mean    2437.631940            NaN                                       NaN
# std     2136.078893            NaN                                       NaN
# min        1.000000            NaN                                       NaN
# 25%      935.250000            NaN                                       NaN
# 50%     2028.500000            NaN                                       NaN
# 75%     3162.750000            NaN                                       NaN
# max     9996.000000            NaN                                       NaN
#
#                        authors   coverType             publisher  edition  \
# count                     3206        3177                  3179      0.0
# unique                    2436           9                   395      NaN
# top     Vários Autores (Autor)  Capa comum  Companhia das Letras      NaN
# freq                        33        2653                   192      NaN
# mean                       NaN         NaN                   NaN      NaN
# std                        NaN         NaN                   NaN      NaN
# min                        NaN         NaN                   NaN      NaN
# 25%                        NaN         NaN                   NaN      NaN
# 50%                        NaN         NaN                   NaN      NaN
# 75%                        NaN         NaN                   NaN      NaN
# max                        NaN         NaN                   NaN      NaN
#
#                publicationDate rankingCategory category1  \
# count                      372            2958      2918
# unique                     310               1         1
# top     5 de fevereiro de 2014          Livros    Livros
# freq                         5            2958      2918
# mean                       NaN             NaN       NaN
# std                        NaN             NaN       NaN
# min                        NaN             NaN       NaN
# 25%                        NaN             NaN       NaN
# 50%                        NaN             NaN       NaN
# 75%                        NaN             NaN       NaN
# max                        NaN             NaN       NaN
#
#                 ...                  pages  reviewCount       rating  \
# count           ...            3206.000000  3206.000000  3206.000000
# unique          ...                    NaN          NaN          NaN
# top             ...                    NaN          NaN          NaN
# freq            ...                    NaN          NaN          NaN
# mean            ...             381.442457    13.928591     4.469109
# std             ...             254.426566    33.309719     0.527006
# min             ...               4.000000     1.000000     1.000000
# 25%             ...             216.000000     3.000000     4.473275
# 50%             ...             320.000000    10.000000     4.473275
# 75%             ...             472.000000    13.873001     4.800000
# max             ...            4424.000000   755.000000     5.000000
#
#               width       height        depth       weight  \
# count   3206.000000  3206.000000  3206.000000  3206.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean      15.582625    22.543681     2.195187   446.776041
# std        2.630768     2.608409     1.226045   205.155674
# min        2.600000    10.000000     0.200000    18.100000
# 25%       13.800000    20.800000     1.400000   299.000000
# 50%       15.600000    22.800000     2.000000   449.233179
# 75%       16.400000    23.500000     2.800000   558.000000
# max       30.400000    40.900000    16.000000   998.000000
#
#         eigenvector_centrality       degree betweenness_centrality
# count             3.206000e+03  3206.000000            3206.000000
# unique                     NaN          NaN                    NaN
# top                        NaN          NaN                    NaN
# freq                       NaN          NaN                    NaN
# mean              4.749234e-03     7.930131               0.002564
# std               1.670599e-02    17.472513               0.007677
# min               5.842757e-08     1.000000               0.000000
# 25%               4.798824e-06     1.000000               0.000000
# 50%               1.464468e-05     2.000000               0.000217
# 75%               2.184396e-04     5.000000               0.001810
# max               1.928515e-01   198.000000               0.114355
#
# [11 rows x 35 columns]

# %% [markdown]
# Below we can inspect the first rows of data, containing title, price, degree and other centrality measures.

# %%
df.head(10)
# Out:
#    id                                              title  \
# 0   1  The Stanford Mathematics Problem Book: With Hi...
# 1   2                                     Fourier Series
# 2   3               Probability Theory: A Concise Course
# 3   4  Vectors, Tensors and the Basic Equations of Fl...
# 4   5                    Ordinary Differential Equations
# 5   6            The Variational Principles of Mechanics
# 6   7                A First Look at Perturbation Theory
# 7   8  Thermodynamics and the Kinetic Theory of Gases...
# 8   9                                          Mechanics
# 9  10                         Statistical Thermodynamics
#
#                                         url                       authors  \
# 0  https://www.amazon.com.br/dp/0486469247/         George Polya (Autor),
# 1  https://www.amazon.com.br/dp/0486633179/    Georgi P. Tolstov (Autor),
# 2  https://www.amazon.com.br/dp/0486635449/        Y. A. Rozanov (Autor),
# 3  https://www.amazon.com.br/dp/0486661105/      Rutherford Aris (Autor),
# 4  https://www.amazon.com.br/dp/0486649407/     Morris Tenenbaum (Autor),
# 5  https://www.amazon.com.br/dp/0486650677/    Cornelius Lanczos (Autor),
# 6  https://www.amazon.com.br/dp/0486675513/     James G. Simmonds (Autor)
# 7  https://www.amazon.com.br/dp/0486414612/       Wolfgang Pauli (Autor),
# 8  https://www.amazon.com.br/dp/0486607542/  Jacob P. Den Hartog (Autor),
# 9  https://www.amazon.com.br/dp/0486661016/    Erwin Schrodinger (Autor),
#
#     coverType                publisher  edition          publicationDate  \
# 0  Capa comum       Dover Publications      NaN  19 de fevereiro de 2009
# 1  Capa comum       Dover Publications      NaN       1 de junho de 1976
# 2  Capa comum       Dover Publications      NaN                      NaN
# 3  Capa comum       Dover Publications      NaN                      NaN
# 4  Capa comum       Dover Publications      NaN                      NaN
# 5  Capa comum       Dover Publications      NaN                      NaN
# 6  Capa comum  Dover Publications Inc.      NaN                      NaN
# 7  Capa comum       Dover Publications      NaN    18 de outubro de 2010
# 8  Capa comum       Dover Publications      NaN       1 de junho de 1961
# 9  Capa comum       Dover Publications      NaN                      NaN
#
#   rankingCategory category1          ...            pages reviewCount  \
# 0          Livros    Livros          ...             68.0    1.000000
# 1          Livros    Livros          ...            352.0    3.000000
# 2          Livros    Livros          ...            160.0   13.873001
# 3          Livros    Livros          ...            320.0    2.000000
# 4          Livros    Livros          ...            848.0    4.000000
# 5          Livros    Livros          ...            418.0    1.000000
# 6          Livros    Livros          ...            160.0   13.873001
# 7          Livros    Livros          ...            160.0    2.000000
# 8          Livros    Livros          ...            480.0   13.873001
# 9          Livros    Livros          ...            112.0   13.873001
#
#      rating width height depth  weight  eigenvector_centrality  degree  \
# 0  4.000000  14.0   21.0   0.6   181.0                0.012593      19
# 1  4.600000  14.6   21.0   1.9   363.0                0.053497      62
# 2  4.473275  14.4   20.8   0.8   200.0                0.034535      59
# 3  4.500000  13.7   21.5   1.6   381.0                0.011868      18
# 4  4.500000  13.8   21.8   4.0   939.0                0.074795      88
# 5  5.000000  13.8   21.5   2.2   581.0                0.050004      43
# 6  4.473275  13.7   21.5   0.8   159.0                0.008733       9
# 7  5.000000  13.8   21.6   1.0   159.0                0.004537      10
# 8  4.473275  13.6   20.3   2.3   522.0                0.019512      23
# 9  4.473275  14.0   20.3   1.3   159.0                0.007206      15
#
#   betweenness_centrality
# 0               0.008232
# 1               0.007205
# 2               0.012235
# 3               0.005312
# 4               0.018363
# 5               0.012020
# 6               0.003138
# 7               0.011852
# 8               0.002422
# 9               0.009045
#
# [10 rows x 35 columns]

# %% [markdown]
# ## Random forest using degree as feature, price as target

# %% [markdown]
# ### Preparing data

# %%
df_with_dummies = pd.get_dummies(df[["id"] + numeric_features + categorical_features + ['price']],columns=categorical_features,drop_first=True)

# %%
feature_list = list(df_with_dummies.drop(columns = ['price']))
features = np.array(df_with_dummies.drop(columns = ['price']))
target = np.array(df_with_dummies['price'])

# %% [markdown]
# ### Average price as baseline

# %% [markdown]
# It's important to have a baseline, so we can validate our predictions after running our model. One easy choice for baseline is the average price of a book.
#
# We have an average price around R\$43, so this means that a very easy prediction would be to always guess R$43 for the price of any book.

# %%
average_target = np.average(target)
print "Average price: R$", average_target
# Out:
# Average price: R$ 105.263334373

# %% [markdown]
# ### Training data split

# %% [markdown]
# Let's split our dataset into two sets: train and test. We use the first to train or model, and we use the second to test the precision of our model.

# %%
features
# Out:
# array([[  1.00000000e+00,   1.90000000e+01,   1.25927224e-02, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  2.00000000e+00,   6.20000000e+01,   5.34965540e-02, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  3.00000000e+00,   5.90000000e+01,   3.45353922e-02, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        ...,
#        [  9.98800000e+03,   5.00000000e+00,   6.82554542e-03, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  9.99100000e+03,   4.00000000e+00,   1.78128222e-03, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  9.99600000e+03,   1.00000000e+00,   1.37531391e-05, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
# Split the data into training and testing sets
train_features, test_features, train_target, test_target \
    = train_test_split(features, target, test_size = 0.25)

# Summary
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_target.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_target.shape)
# Out:
# ('Training Features Shape:', (2404, 1089))
# ('Training Labels Shape:', (2404,))
# ('Testing Features Shape:', (802, 1089))
# ('Testing Labels Shape:', (802,))

# %% [markdown]
# ### Train data

# %% [markdown]
# We train a random forest model with 500 estimators.

# %%
# Load model
rf = RandomForestRegressor(n_estimators = 500)
# Train
rf.fit(train_features[:, 1:], train_target);

# %% [markdown]
# ### Prediction

# %%
predictions = rf.predict(test_features[:, 1:])

# %% [markdown]
# ####  List of most important features

# %%
importance = zip(feature_list, rf.feature_importances_)
importance.sort(key=lambda x:-x[1])
pd.DataFrame(importance).head(200)
# Out:
#                                                      0         1
# 0                                               degree  0.288178
# 1                                          reviewCount  0.186003
# 2                           language_Português, Inglês  0.077648
# 3                                publisher_Cengage CTP  0.065279
# 4                               eigenvector_centrality  0.043471
# 5                                               weight  0.041203
# 6                                 coverType_Capa comum  0.040877
# 7                                               height  0.033699
# 8                                                   id  0.024434
# 9                                   category2_Infantil  0.024278
# 10                                               width  0.023367
# 11                              betweenness_centrality  0.022542
# 12                                               pages  0.015124
# 13                                 publisher_Wiley VCH  0.012761
# 14                                      publisher_Buzz  0.009223
# 15                               publisher_McGraw-Hill  0.008677
# 16                     publisher_Jelezky Publishing Ug  0.008062
# 17                  publisher_Academia de Inteligência  0.005141
# 18                            publisher_Westview Press  0.005064
# 19                              category7_Neurociência  0.004585
# 20                         publisher_Cambridge English  0.004407
# 21                   publisher_Sourcebooks Jabberwocky  0.003793
# 22                                               depth  0.003595
# 23                    publisher_W. W. Norton & Company  0.003422
# 24                               publisher_Brooks Cole  0.003280
# 25                               publisher_Paz e Terra  0.003151
# 26                         category6_Análise Funcional  0.003092
# 27                         publisher_Portfolio-Penguin  0.003005
# 28                          category3_Ciências Sociais  0.002877
# 29                                             ranking  0.001715
# ..                                                 ...       ...
# 170  publisher_Scientific American / Farrar, Straus...  0.000017
# 171               publisher_Editora do Brasil Didático  0.000016
# 172                                 category5_Zoologia  0.000016
# 173                                     publisher_L&PM  0.000016
# 174                                    publisher_Mises  0.000015
# 175                                publisher_Teosófica  0.000015
# 176                                   publisher_Matrix  0.000015
# 177                          publisher_Primeira Pessoa  0.000015
# 178                    category2_Jovens e Adolescentes  0.000014
# 179                               publisher_Birkhäuser  0.000014
# 180                              publisher_For Dummies  0.000014
# 181                                category3_Filosofia  0.000014
# 182                   publisher_Addison Wesley Longman  0.000014
# 183               category2_Religião e Espiritualidade  0.000014
# 184                          category4_Matemática Pura  0.000014
# 185                         category6_Flores e plantas  0.000013
# 186                            category4_Alfabetização  0.000013
# 187                                    publisher_Petit  0.000013
# 188                            category4_Epistemologia  0.000013
# 189                             publisher_José Olympio  0.000013
# 190                                category4_Filósofos  0.000012
# 191                    publisher_Jelezky Publishing UG  0.000012
# 192                             publisher_Pocket Books  0.000012
# 193                       category4_Ética e Moralidade  0.000012
# 194         category2_Crônicas, Humor e Entretenimento  0.000012
# 195                 category5_Consciência e Pensamento  0.000011
# 196                                     publisher_Wspc  0.000011
# 197                                 category5_Botânica  0.000011
# 198                                   publisher_Manole  0.000011
# 199                                 publisher_Tusquets  0.000011
#
# [200 rows x 2 columns]

# %% [markdown]
# ####  Preço previsto vs. Preço real

# %%
plt.figure(figsize=(8,8), dpi=130)
plt.scatter(test_target, predictions, 100, alpha=0.05, edgecolors="none")
baseline = [0, np.max(test_target)]
plt.plot(baseline, baseline, "--", color="green", label = u"Preço previsto = Preço real")
ax = plt.gca()
ax.set_ylabel(u"Preço previsto (R$)")
ax.set_xlabel(u"Preço real (R$)")
ax.legend()
plt.title(u"Preço previsto vs. Preço real")
plt.axes().set_aspect('equal', 'datalim')
#plt.xlim(0, 150)
#plt.ylim(0, 150)
plt.show()

# %% [markdown]
# ### Mean absolute error

# %% [markdown]
# Now we can compare the errors obtained by our predictions against the errors provided by the baseline (average price). Our prediction errors should be less than the baseline errors to consider the model successful.

# %%
# Calculate the absolute errors
errors = abs(predictions - test_target)
errors_baseline = abs(average_target - test_target)
# Print out the mean absolute error (mae)
print('Mean absolute prediction error: R$', round(np.mean(errors), 2))
print('Mean absolute error using average: R$',
      round(np.mean(errors_baseline), 2))
# Out:
# ('Mean absolute prediction error: R$', 42.0)
# ('Mean absolute error using average: R$', 105.84)

# %% [markdown]
# ### Worst predictions

# %% [markdown]
# Below we can inspect the rows with the biggest prediction error.

# %%
pd.set_option('display.max_columns', None)
data = {
    "all_features": test_features.tolist(),
    "id": test_features[:, 0],
    "target": test_target,
    "prediction": predictions,
    "error": errors,
    "errors_baseline": errors_baseline
}
predicted_df = pd.DataFrame(data = data)
joined_predicted_df = predicted_df
joined_predicted_df = predicted_df.set_index("id").join(df.set_index("id"))
joined_predicted_df.sort_values('error', ascending = False).head(20)
# Out:
#                                              all_features       error  \
# id
# 1685.0  [1685.0, 13.0, 0.0210742948347, 0.000831716000...  2260.17580
# 1991.0  [1991.0, 4.0, 0.0033865608127, 0.0011249337303...  1601.90980
# 1937.0  [1937.0, 1.0, 0.000833400145341, 0.0, 44166.53...  1061.58480
# 2024.0  [2024.0, 2.0, 0.00237144912194, 0.000419829983...   968.82538
# 1904.0  [1904.0, 1.0, 0.00170151004535, 0.0, 44166.536...   841.99608
# 1701.0  [1701.0, 10.0, 0.0152786752493, 0.001446816838...   814.86304
# 1965.0  [1965.0, 2.0, 0.00500959029659, 9.60252025877e...   613.89932
# 1866.0  [1866.0, 6.0, 0.0117848677313, 0.0003786961749...   609.18700
# 1981.0  [1981.0, 10.0, 0.0127401800865, 0.003422396806...   557.76734
# 1910.0  [1910.0, 17.0, 0.0353581547056, 0.001911259146...   505.57374
# 1785.0  [1785.0, 3.0, 0.00611657810184, 0.000452719534...   502.37298
# 2148.0  [2148.0, 15.0, 0.0293368531609, 0.003358735514...   478.71098
# 2198.0  [2198.0, 2.0, 0.00421023075857, 0.000331767751...   461.44214
# 2174.0  [2174.0, 2.0, 0.000455621109722, 0.00088690418...   441.00258
# 1943.0  [1943.0, 12.0, 0.0239760040587, 0.001763189440...   424.84936
# 2200.0  [2200.0, 3.0, 0.00281767416759, 0.001395357869...   406.60744
# 1702.0  [1702.0, 16.0, 0.0245830464481, 0.001810497893...   404.33422
# 1688.0  [1688.0, 6.0, 0.00647771648418, 0.000615875699...   340.78018
# 1970.0  [1970.0, 1.0, 0.001082656795, 0.0, 44166.53613...   340.07278
# 1982.0  [1982.0, 1.0, 0.001082656795, 0.0, 44166.53613...   304.56640
#
#         errors_baseline  prediction   target  \
# id
# 1685.0      2425.806666   270.89420  2531.07
# 1991.0      1996.276666   499.63020  2101.54
# 1937.0      1161.096666   204.77520  1266.36
# 2024.0       104.166666  1178.25538   209.43
# 1904.0       980.666666   243.93392  1085.93
# 1701.0                         Peter J. Eccles (Autor)   Capa dura
# 1965.0                      David J. Griffiths (Autor)         NaN
# 1866.0                          Craig P. Bauer (Autor)   Capa dura
# 1981.0                               Ken Dill (Autor),  Capa comum
# 1910.0                            Randy Harris (Autor)   Capa dura
# 1785.0                            Peter Wittek (Autor)  Capa comum
# 2148.0                           Rob Phillips (Autor),  Capa comum
# 2198.0                        Brian W. Pfennig (Autor)   Capa dura
# 2174.0                           Laszlo Kurti (Autor),  Capa comum
# 1943.0                       Joseph W. Goodman (Autor)   Capa dura
# 2200.0                       Douglas A. Skoog (Autor),   Capa dura
# 1702.0                  Patrick M. Fitzpatrick (Autor)   Capa dura
# 1688.0                         Sheldon M. Ross (Autor)   Capa dura
# 1970.0  Randall D. Knight (Professor Emeritus) (Autor)   Capa dura
# 1982.0                         James M. Leake (Autor),  Capa comum
#
#                                    publisher  edition         publicationDate  \
# id
# 1685.0  McGraw-Hill Science/Engineering/Math      NaN                     NaN
# 1991.0  McGraw-Hill Science/Engineering/Math      NaN                     NaN
# 1937.0            Cambridge University Press      NaN  13 de dezembro de 1997
# 2024.0                       Sams Publishing      NaN                     NaN
# 1904.0                               Pearson      NaN                     NaN
# 1701.0            Cambridge University Press      NaN  11 de dezembro de 1997
# 1965.0                                   NaN      NaN                     NaN
# 1866.0            Princeton University Press      NaN     13 de junho de 2017
# 1981.0                    Garland Publishing      NaN                     NaN
# 1910.0                Addison Wesley Longman      NaN                     NaN
# 1785.0                        Academic Press      NaN                     NaN
# 2148.0                    Garland Publishing      NaN                     NaN
# 2198.0                       Wiley-Blackwell      NaN                     NaN
# 2174.0                        Academic Press      NaN                     NaN
# 1943.0                         W. H. Freeman      NaN                     NaN
# 2200.0                      Cengage Learning      NaN                     NaN
# 1702.0                           Brooks Cole      NaN                     NaN
# 1688.0                        Academic Press      NaN                     NaN
# 1970.0                               Pearson      NaN                     NaN
# 1982.0                     John Wiley & Sons      NaN                     NaN
#
#        rankingCategory category1                category2  \
# id
# 1685.0             NaN       NaN                      NaN
# 1991.0             NaN       NaN                      NaN
# 1937.0             NaN       NaN                      NaN
# 2024.0             NaN       NaN                      NaN
# 1904.0             NaN       NaN                      NaN
# 1701.0             NaN       NaN                      NaN
# 1965.0             NaN       NaN                      NaN
# 1866.0             NaN       NaN                      NaN
# 1981.0             NaN       NaN                      NaN
# 1910.0             NaN       NaN                      NaN
# 1785.0             NaN       NaN                      NaN
# 2148.0             NaN       NaN                      NaN
# 2198.0             NaN       NaN                      NaN
# 2174.0          Livros    Livros  Inglês e Outras Línguas
# 1943.0             NaN       NaN                      NaN
# 2200.0          Livros    Livros  Inglês e Outras Línguas
# 1702.0             NaN       NaN                      NaN
# 1688.0          Livros    Livros  Inglês e Outras Línguas
# 1970.0             NaN       NaN                      NaN
# 1982.0             NaN       NaN                      NaN
#
#                     category3 category4  category5 category6 category7  \
# id
# 1685.0                    NaN       NaN        NaN       NaN       NaN
# 1991.0                    NaN       NaN        NaN       NaN       NaN
# 1937.0                    NaN       NaN        NaN       NaN       NaN
# 1454.0     Applied Mathematics: A Very Short Introduction
# 1313.0           Investigação Sobre o Entendimento Humano
# 3545.0                               O Cemitério De Praga
# 1432.0          Existentialism: A Very Short Introduction
# 1470.0             Freemasonry: A Very Short Introduction
#
#                                              url  \
# id
# 116.0   https://www.amazon.com.br/dp/8535911324/
# 546.0   https://www.amazon.com.br/dp/8576573113/
# 1211.0  https://www.amazon.com.br/dp/0465026567/
# 1336.0  https://www.amazon.com.br/dp/8535922008/
# 2789.0  https://www.amazon.com.br/dp/8537813583/
# 2313.0  https://www.amazon.com.br/dp/8535930140/
# 2879.0  https://www.amazon.com.br/dp/8576089068/
# 383.0   https://www.amazon.com.br/dp/8539306611/
# 1653.0  https://www.amazon.com.br/dp/8536319216/
# 967.0   https://www.amazon.com.br/dp/8531400937/
# 8297.0  https://www.amazon.com.br/dp/8582175094/
# 5673.0  https://www.amazon.com.br/dp/8572449418/
# 3016.0  https://www.amazon.com.br/dp/8552000288/
# 3337.0  https://www.amazon.com.br/dp/8525051861/
# 2747.0  https://www.amazon.com.br/dp/8576570416/
# 1454.0  https://www.amazon.com.br/dp/0198754043/
# 1313.0  https://www.amazon.com.br/dp/8577151417/
# 3545.0  https://www.amazon.com.br/dp/8501092843/
# 1432.0  https://www.amazon.com.br/dp/0192804286/
# 1470.0  https://www.amazon.com.br/dp/0198796277/
#
#                                            authors       coverType  \
# id
# 116.0                           Carl Sagan (Autor)      Capa comum
# 546.0                   Ievgueni Zamiatin (Autor),       Capa dura
# 1211.0               Douglas R. Hofstadter (Autor)      Capa comum
# 1336.0                     António Damásio (Autor)      Capa comum
# 2789.0                        Victor Hugo (Autor),       Capa dura
# 2313.0                          Jô Soares (Autor),      Capa comum
# 2879.0                    Nobrega Clemente (Autor)      Capa comum
# 383.0                        Lamont Peter (Autor),      Capa comum
# 1653.0                        David Sadava (Autor)      Capa comum
# 967.0                  Ludwig Wittgenstein (Autor)      Capa comum
# 8297.0                    Giorgio Agamben (Autor),      Capa comum
# 5673.0  Maria Lúcia Garcia Pallares-Burke (Autor),   Capa flexível
# 3016.0                   Vassily Tchuikov (Autor),      Capa comum
# 3337.0                        Nigel Cliff (Autor),      Capa comum
# 2747.0                        Isaac Asimov (Autor)      Capa comum
# 1454.0                       Alain Goriely (Autor)      Capa comum
# 1313.0                         David Hume (Autor),  Livro de bolso
# 3545.0                         Umberto Eco (Autor)      Capa comum
# 1432.0                        Thomas Flynn (Autor)      Capa comum
# 1470.0                   Andreas Önnerfors (Autor)      Capa comum
#
#                            publisher  edition  \
# id
# 116.0           Companhia das Letras      NaN
# 546.0                          Aleph      NaN
# 1211.0                   Basic Books      NaN
# 1336.0          Companhia das Letras      NaN
# 2789.0                         Zahar      NaN
# 2313.0          Companhia das Letras      NaN
# 2879.0                    Alta Books      NaN
# 383.0                          UNESP      NaN
# 1653.0                        Artmed      NaN
# 967.0                           EESC      NaN
# 8297.0                     Autêntica      NaN
# 5673.0                      Contexto      NaN
# 3016.0                      Contexto      NaN
# 3337.0                         Globo      NaN
# 2747.0                         Aleph      NaN
# 1454.0                    OUP Oxford      NaN
# 1313.0                         Hedra      NaN
# 3545.0                        Record      NaN
# 1432.0  Oxford University Press, USA      NaN
# 1470.0                    OUP Oxford      NaN
#
#                                           publicationDate rankingCategory  \
# id
# 116.0                                                 NaN          Livros
# 546.0                                                 NaN          Livros
# 1211.0  AZ); Edição: 20th Anniversary ed. (5 de fevere...          Livros
# 1336.0                                                NaN          Livros
# 2789.0                                                NaN          Livros
# 2313.0                                                NaN          Livros
# 2879.0                                                NaN          Livros
# 383.0                                                 NaN          Livros
# 1653.0                                                NaN          Livros
# 967.0                                                 NaN          Livros
# 8297.0                                                NaN          Livros
# 5673.0                                                NaN          Livros
# 3016.0                                                NaN          Livros
# 3337.0                                                NaN          Livros
# 2747.0                                                NaN          Livros
# 1454.0                            22 de fevereiro de 2018          Livros
# 1313.0                                                NaN          Livros
# 3545.0                                                NaN          Livros
# 1432.0                              1 de setembro de 2006             NaN
# 1470.0                               24 de agosto de 2017          Livros
#
#        category1                               category2  \
# id
# 116.0     Livros                                Ciências
# 546.0     Livros    Fantasia, Horror e Ficção Científica
# 1211.0    Livros                 Inglês e Outras Línguas
# 1336.0    Livros                         Saúde e Família
# 2789.0    Livros                     Literatura e Ficção
# 2313.0    Livros            Biografias e Histórias Reais
# 2879.0    Livros      Administração, Negócios e Economia
# 383.0     Livros  Política, Filosofia e Ciências Sociais
# 1653.0    Livros                                Ciências
# 967.0     Livros  Política, Filosofia e Ciências Sociais
# 8297.0    Livros  Política, Filosofia e Ciências Sociais
# 5673.0    Livros                                História
# 3016.0    Livros                                História
# 3337.0    Livros                                História
# 2747.0    Livros    Fantasia, Horror e Ficção Científica
# 1454.0    Livros                 Inglês e Outras Línguas
# 1313.0    Livros  Política, Filosofia e Ciências Sociais
# 3545.0    Livros                                 Romance
# 1432.0       NaN                                     NaN
# 1470.0    Livros                 Inglês e Outras Línguas
#
#                                      category3             category4  \
# id
# 116.0                    Ensaios e Comentários                   NaN
# 546.0                                 Fantasia                   NaN
# 1211.0  Política, Filosofia e Ciências Sociais             Filosofia
# 1336.0                            Saúde Mental               Emoções
# 2789.0                     Literatura Clássica                   NaN
# 2313.0                                Memórias                   NaN
# 2879.0                                     NaN                   NaN
# 383.0                         Ciências Sociais  Costumes e Tradições
# 1653.0                     Ciências Biológicas              Biologia
# 967.0                                Filosofia                   NaN
# 8297.0                               Filosofia                   NaN
# 5673.0                                  Europa                   NaN
# 3016.0                                 Militar                   NaN
# 3337.0                                     NaN                   NaN
# 2747.0                       Ficção Científica              Aventura
# 1454.0                   Ciências Tecnológicas            Matemática
# 1313.0                               Filosofia                   NaN
# 3545.0                                     NaN                   NaN
# 1432.0                                     NaN                   NaN
# 1470.0  Política, Filosofia e Ciências Sociais      Ciências Sociais
#
#                      category5 category6 category7  category8  category9  \
# id
# 116.0                      NaN       NaN       NaN        NaN        NaN
# 546.0                      NaN       NaN       NaN        NaN        NaN
# 1211.0                     NaN       NaN       NaN        NaN        NaN
# 1336.0                     NaN       NaN       NaN        NaN        NaN
# 2789.0                     NaN       NaN       NaN        NaN        NaN
# 2313.0                     NaN       NaN       NaN        NaN        NaN
# 2879.0                     NaN       NaN       NaN        NaN        NaN
# 383.0                      NaN       NaN       NaN        NaN        NaN
# 1653.0      Biologia Molecular       NaN       NaN        NaN        NaN
# 967.0                      NaN       NaN       NaN        NaN        NaN
# 8297.0                     NaN       NaN       NaN        NaN        NaN
# 5673.0                     NaN       NaN       NaN        NaN        NaN
# 3016.0                     NaN       NaN       NaN        NaN        NaN
# 3337.0                     NaN       NaN       NaN        NaN        NaN
# 2747.0                     NaN       NaN       NaN        NaN        NaN
# 1454.0                Aplicada       NaN       NaN        NaN        NaN
# 1313.0                     NaN       NaN       NaN        NaN        NaN
# 3545.0                     NaN       NaN       NaN        NaN        NaN
# 1432.0                     NaN       NaN       NaN        NaN        NaN
# 1470.0  Filantropia e Caridade       NaN       NaN        NaN        NaN
#
#         category10      isbn10          isbn13   language  postProcessed  \
# id
# 116.0          NaN  8535911324  978-8535911329  Português              1
# 546.0          NaN  8576573113  978-8576573111  Português              1
# 1211.0         NaN  0465026567  978-0465026562     Inglês              1
# 1336.0         NaN  8535922008  978-8535922004  Português              1
# 2789.0         NaN  8537813583  978-8537813584  Português              1
# 2313.0         NaN  8535930140  978-8535930146  Português              1
# 2879.0         NaN  8576089068  978-8576089063  Português              1
# 383.0          NaN  8539306611  978-8539306619  Português              1
# 1653.0         NaN  8536319216  978-8536319216  Português              1
# 967.0          NaN  8531400937  978-8531400933  Português              1
# 8297.0         NaN  8582175094  978-8582175095  Português              1
# 5673.0         NaN  8572449418  978-8572449410  Português              1
# 3016.0         NaN  8552000288  978-8552000280  Português              1
# 3337.0         NaN  8525051861  978-8525051868  Português              1
# 2747.0         NaN  8576570416  978-8576570417  Português              1
# 1454.0         NaN  0198754043  978-0198754046     Inglês              1
# 1313.0         NaN  8577151417  978-8577151417  Português              1
# 3545.0         NaN  8501092843  978-8501092847  Português              1
# 1432.0         NaN  0192804286  978-0192804280     Inglês              1
# 1470.0         NaN  0198796277  978-0198796275     Inglês              1
#
#          price        ranking  pages  reviewCount    rating      width  \
# id
# 116.0    46.51   25635.000000  304.0     5.000000  4.700000  13.600000
# 546.0    35.90    2035.000000  344.0    59.000000  4.400000  14.000000
# 1211.0   79.64   19453.000000  824.0     2.000000  5.000000  16.500000
# 1336.0   34.30    1871.000000  264.0    11.000000  4.300000  15.600000
# 2789.0   36.50   11107.000000  624.0    17.000000  4.700000  12.400000
# 2313.0   50.30    7104.000000  480.0    57.000000  4.100000  16.400000
# 2879.0   29.80   71900.000000  192.0     3.000000  5.000000  13.800000
# 383.0    47.30   16831.000000  447.0     2.000000  4.000000  14.000000
# 1653.0  126.85   57220.000000  461.0     2.000000  5.000000  21.200000
# 967.0    35.97    7394.000000  296.0     2.000000  5.000000  15.658864
# 8297.0   30.30   19515.000000  216.0     1.000000  3.000000  15.400000
# 5673.0   41.90   26202.000000  416.0     7.000000  4.800000  16.400000
# 3016.0   40.01   34762.000000  256.0     2.000000  5.000000  15.500000
# 3337.0   42.59   19543.000000  544.0    36.000000  4.100000  15.800000
# 2747.0   27.90    2645.000000  256.0    71.000000  4.500000  13.700000
# 1454.0   38.40  173057.000000  168.0    13.873001  4.473275  11.200000
# 1313.0   27.57   50259.000000  224.0     1.000000  5.000000  11.400000
# 3545.0   40.40   32660.000000  480.0    52.000000  3.600000  15.800000
# 1432.0   41.79   44166.536133  144.0    13.873001  4.473275  10.700000
# 1470.0   39.45  184800.000000  160.0    13.873001  4.473275  10.900000
#
#            height     depth      weight  eigenvector_centrality  degree  \
# id
# 116.0   20.800000  2.600000  821.000000            8.814408e-04      38
# 546.0   21.600000  2.400000  540.000000            2.786768e-05       2
# 1211.0  23.500000  4.400000  449.233179            1.889054e-06       1
# 1336.0  22.400000  1.800000  363.000000            1.304270e-04      12
# 2789.0  17.600000  3.200000  540.000000            5.290251e-07       1
# 2313.0  23.400000  4.400000  916.000000            8.510618e-05       5
# 2879.0  20.800000  1.200000  240.000000            7.681786e-06       1
# 383.0   21.000000  2.600000  540.000000            3.556437e-04      11
# 1653.0  28.000000  2.000000  449.233179            3.027883e-06       1
# 967.0   22.613912  2.214603  349.000000            1.190326e-05       2
# 8297.0  22.400000  1.400000  322.000000            3.065087e-06       1
# 5673.0  21.600000  2.800000  449.233179            1.311454e-05       1
# 3016.0  22.900000  2.300000  381.000000            1.145093e-05       1
# 3337.0  23.000000  3.000000  862.000000            1.311454e-05       1
# 2747.0  21.100000  1.500000  322.000000            3.225430e-05       2
# 1454.0  17.000000  1.000000  132.000000            1.440702e-02      11
# 1313.0  17.400000  1.400000  240.000000            2.488793e-06       1
# 3545.0  22.800000  2.600000  726.000000            9.871846e-06       2
# 1432.0  17.300000  0.800000   59.000000            2.974617e-04       2
# 1470.0  17.000000  1.000000   99.800000            1.434293e-04       1
#
#         betweenness_centrality
# id
# 116.0                 0.007493
# 546.0                 0.000729
# 1211.0                0.000000
# 1336.0                0.004834
# 2789.0                0.000000
# 2313.0                0.001717
# 2879.0                0.000000
# 383.0                 0.004694
# 1653.0                0.000000
# 967.0                 0.003575
# 8297.0                0.000000
# 5673.0                0.000000
# 3016.0                0.000000
# 3337.0                0.000000
# 2747.0                0.000265
# 1454.0                0.003198
# 1313.0                0.000000
# 3545.0                0.000697
# 1432.0                0.000211
# 1470.0                0.000000

# %%
predicted_df.describe()
# Out:
#              error  errors_baseline           id   prediction       target
# count   802.000000       802.000000   802.000000   802.000000   802.000000
# mean     41.998072       105.843625  2383.607232   104.131150   108.260823
# std     136.576489       197.599671  2023.978155   182.211368   224.172908
# min       0.015340         0.663334     3.000000    12.465780     2.990000
# 25%       4.409570        51.499167   887.500000    32.005385    29.800000
# 50%      10.531785        68.518334  2031.500000    43.710865    44.005000
# 75%      23.221330        81.363334  3157.750000    80.062480    75.537500
# max    2260.175800      2425.806666  9991.000000  1667.847220  2531.070000

# %% [markdown]
# ### Visualize decision tree

# %%
# Pull out one tree from the forest
tree = rf.estimators_[0]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot',
                feature_names = feature_list, rounded = True)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')

# %% [markdown]
# <img src="files/image.png">
